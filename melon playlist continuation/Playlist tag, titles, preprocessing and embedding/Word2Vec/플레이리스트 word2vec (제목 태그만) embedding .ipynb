# %%
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from time import time
import json
plt.style.use('seaborn')
sns.set_palette("hls")
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
train_df = pd.read_json('../train_df(filtered_title(특수기호 안 없앰)).json')
train_df
# Out:
#                    tags      id                             plylst_title  \
# 0       [힐링, 휴식, 밤, 새벽]  147668                          to. 힘들고 지친 분들에게
# 1                   [팝]   50422                                 130807-7
# 2                [뉴에이지]  116432                   숙면을 위한 슬픈 마음을 달래 줄 피아노
# 3       [하드락, 록스피릿, 댄스]   55076                           당신을 하얗게 불태울 곡들
# 4        [힐링, 휴식, 기분전환]  125064  [스피커 필수 / hiphop] 듣고 있음 꿀렁꿀렁이고 싶은 힙합음악!
# ...                 ...     ...                                      ...
# 115066               []  132039                   이것만 알아도 브릿팝 안다는 소리듣는다.
# 115067               []   21475                                  make015
# 115068   [힘들때, 지칠때, 힘내]   81196                       힘든 걸 알아, 말해주고 싶었어요
# 115069               []  151600                        ♥christmas music♥
# 115070               []    7706                                  라디오 389
#
#                                                     songs  like_cnt  \
# 0       [663185, 649626, 6855, 188486, 348451, 169945,...        12
# 1       [627035, 256438, 603324, 200889, 441319, 21689...         0
# 2       [129204, 369497, 649743, 344619, 110281, 63266...        23
# 3       [677591, 420396, 104934, 119279, 251988, 58850...         1
# 4       [704455, 694036, 508043, 154933, 57614, 645195...       715
# ...                                                   ...       ...
# 115066  [8778, 5725, 234307, 64368, 691112, 581349, 40...       232
# 115067  [470489, 72225, 387567, 328452, 517417, 690761...         0
# 115068  [448250, 131741, 531820, 616260, 639943, 13129...        13
# 115069                                                 []         8
# 115070                   [243082, 383812, 218279, 297891]         7
#
#                       updt_date                             tokenized_title  \
# 0       2016-06-23 10:06:27.000                              [힘들다, 지치다, 분들]
# 1       2013-08-15 13:17:11.000                                  [130807-7]
# 2       2015-09-03 16:51:50.000                      [숙면, 슬프다, 마음, 달래, 피아노]
# 3       2017-01-09 15:41:25.000                        [당신, 하얗다, 불, 태우다, 곡]
# 4       2016-02-22 12:32:50.000  [스피커, 필수, hiphop, 듣다, 꿀렁꿀렁, 싶다, 힙합, 음악, !]
# ...                         ...                                         ...
# 115066  2014-03-10 19:08:16.000                               [브릿팝, 소리, 듣다]
# 115067  2016-05-16 15:34:18.000                                 [make, 015]
# 115068  2017-12-20 16:32:07.000                         [힘드다, 말, 해주, 고, 싶다]
# 115069  2015-12-23 09:38:19.000                    [♥, christmas, music, ♥]
# 115070  2009-10-01 13:58:17.000                                  [라디오, 389]
#
#                                                title_tags
# 0                           [힐링, 휴식, 밤, 새벽, 힘들다, 지치다, 분들]
# 1                                           [팝, 130807-7]
# 2                            [뉴에이지, 숙면, 슬프다, 마음, 달래, 피아노]
# 3                     [하드락, 록스피릿, 댄스, 당신, 하얗다, 불, 태우다, 곡]
# 4       [힐링, 휴식, 기분전환, 스피커, 필수, hiphop, 듣다, 꿀렁꿀렁, 싶다, ...
# ...                                                   ...
# 115066                                      [브릿팝, 소리, 듣다]
# 115067                                        [make, 015]
# 115068                  [힘들때, 지칠때, 힘내, 힘드다, 말, 해주, 고, 싶다]
# 115069                           [♥, christmas, music, ♥]
# 115070                                         [라디오, 389]
#
# [115071 rows x 8 columns]

# %%
train_word = []
for i in tqdm(range(len(train_df))):
    train_word.append(train_df.iloc[i]['title_tags'])
train_word
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 115071/115071 [00:06<00:00, 18954.11it/s]
# [['힐링', '휴식', '밤', '새벽', '힘들다', '지치다', '분들'],
#  ['팝', '130807-7'],
#  ['뉴에이지', '숙면', '슬프다', '마음', '달래', '피아노'],
#  ['하드락', '록스피릿', '댄스', '당신', '하얗다', '불', '태우다', '곡'],
#  ['힐링',
#   '휴식',
#   '기분전환',
#   '스피커',
#   '필수',
#   'hiphop',
#   '듣다',
#   '꿀렁꿀렁',
#   '싶다',
#   '힙합',
#   '음악',
#   '!'],
#  ['요즘듣는노래', '요즘', '듣다', '노래', '2'],
#  ['카페', '인디', 'tthing', '하루'],
#  ['로우파이', '감성', '자기전에듣기좋은', '알앤비힙합', '분위기', 'lofi', 'rnb', '모음'],
#  ['댄스',
#   'EDM',
#   '가을',
#   '하늘',
#   'edm',
#   '함께',
#   '!',
#   '일',
#   '렉',
#   '트릭',
#   '스카이',
#   '뮤직',
#   '페스티벌',
#   '프리뷰'],
#  ['발라드', '발라드', '감성', '재'],
#  ['휴식',
#   '힐링',
#   '여행',
#   '산책',
#   '♤',
#   '겨울',
#   '이면',
#   '생각',
#   '나',
#   '늘다',
#   '들려오다',
#   '노래',
#   '들다',
#   '♤'],
#  ['밤', '까페', '새벽', '한중일', '꿀', '보이스', '삼대', '장'],
#  ['발라드', '늦다', '봄', '이별', '후'],
#  ['일렉', 'game'],
#  ['내한',
#   '감성',
#   '취향저격',
#   '팝',
#   '인디팝',
#   '밴드',
#   '레이니',
#   '음색',
#   '록',
#   'LANY',
#   'lany',
#   'live',
#   'in',
#   'seoul',
#   '2019',
#   '내한',
#   '예상',
#   '세트리스트'],
#  ['카페', '피아노', '뉴에이지', '봄', '재즈', '따뜻하다', '봄날', '달달', '피아노', '뮤직'],
#  ['슬픔', '이별', '설렘', '사랑', '방대', '양', '듀엣곡', '종결', '리스트'],
#  ['감성', '밤', '알앤비', '#rnb', 'soul'],
#  ['몽롱',
#   'Rock',
#   '명곡',
#   '락발라드',
#   '해외락',
#   '기분전환',
#   'Soft_Rock',
#   '락음악',
#   '부드러운',
#   '감성락',
#   '몽롱',
#   '감성',
#   '락',
#   '!',
#   '시끄럽다',
#   '락',
#   '아니다',
#   '락',
#   '발라드',
#   '!',
#   '명곡',
#   '쏟아',
#   '지다',
#   '!!'],
#  ['히피', '히피', '집시', '이다'],
#  ['발라드', '내', '스타일', '심야', '데이트'],
#  ['기분전환', '여행', '드라이브', '신나는', '룰루', '드라이빙', '뮤직', '!'],
#  ['아침',
#   '운동',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '스트레스',
#   '신나는',
#   '❤',
#   'dj',
#   '추천',
#   '1월',
#   '신곡',
#   '일렉트로니카',
#   '모음',
#   '❤'],
#  ['설렘', '사랑', '잔잔', '여름'],
#  ['휴식', '힐링', '설렘', '사랑', '20', '대다', '후반', '친구', '들다', '들다', '좋다', '노래'],
#  ['록메탈', 'Pop', 'pop', '순이', '추', '천하', 'fall', 'out', 'boy'],
#  ['크리스마스', '재즈', 'christmas', 'jazz', '3', '크리스마스', '재즈', '죠', '!'],
#  ['발라드', 'super', 'ballads', '1'],
#  ['잔잔한',
#   '감성',
#   '밤',
#   '새벽',
#   '취향저격',
#   '발라드',
#   '사랑',
#   '내',
#   '맘',
#   '속',
#   '차트',
#   '늘',
#   '상위',
#   '권',
#   ':)'],
#  ['힐링', '휴식', '밤', '새벽', '좋다', '피아노', '곡', '모음', 'ver', '3'],
#  ['피아노', '감정', '잡기', '좋다', '피아노', '곡'],
#  ['감성',
#   '밤',
#   '발라드',
#   '추억',
#   '드라이브',
#   '2000년대',
#   '사랑',
#   '이별',
#   '질리',
#   '지',
#   '않다',
#   '2000',
#   '년대',
#   '명품',
#   '발라드',
#   '모음'],
#  ['슬픔', '추억', '이별', '회상', '우리', '들다', '곡'],
#  ['힙합',
#   '발라드',
#   '댄스',
#   '플레이리스트',
#   '이것저것',
#   '랜덤',
#   '팝송',
#   '팝',
#   '인생곡',
#   '인생',
#   '곡',
#   '플레이',
#   '리스트'],
#  ['나만의차트', '댄스', '추억', '발라드', '2011', '플레이', '리스트'],
#  ['힙합',
#   '리듬',
#   '국내힙합',
#   '남다른',
#   'HipHop',
#   '비트',
#   '사운드',
#   '힙해',
#   '남',
#   '다른',
#   'sound',
#   '선',
#   '보이',
#   '국내',
#   'hiphop'],
#  ['감성',
#   '가을',
#   '새벽',
#   '우울',
#   '발라드',
#   '가요',
#   '사랑',
#   '이별',
#   '우울',
#   '날',
#   '듣다',
#   '싶다',
#   '노래',
#   '들다'],
#  ['드라이브', '밤', '새벽', '내', '취향', '저격', '느낌', '노래', '모음'],
#  ['힐링', '휴식', '기분전환', '테마', '봄', '들다', '딱', '좋다', '상큼', '하우스', '누', '디스코'],
#  ['잔잔한', '밤', '새벽', '잠들다', '기전', '이렇다', '감성', '어떻다', '?'],
#  ['10살', '아기동화', '두', '두루미', '들려주다', '이야기'],
#  ['최신음악', '오늘', '최신', '음악', '들다', '볼', '래', '?'],
#  ['팝송', '기분전환', '남성보컬', '잔잔한', '보이스', '좋다', '남성', '팝송', '베스트'],
#  ['발라드', '2004년', '그해', '겨울', '따뜻하다'],
#  ['식욕',
#   '겨울',
#   '봄',
#   '겨울여행',
#   '봄날',
#   '기분전환',
#   '입춘',
#   '눈',
#   '맛있는',
#   '꽃샘추위',
#   '눈',
#   '오다',
#   '겨울',
#   '보내다',
#   '봄',
#   '기',
#   '다리',
#   '면서',
#   '맛있다',
#   '노래',
#   '함께'],
#  ['샤워',
#   '출근길',
#   '집으로',
#   '등교길',
#   '어디서들어본노래',
#   '산책',
#   '퇴근길',
#   '내',
#   '들다',
#   '려고',
#   '만들다',
#   '팝송',
#   '플레이',
#   '리스트'],
#  ['목요일', '#', '목요일'],
#  ['발라드', '겨울', '이면', '생각', '나', '늘다', '노래'],
#  ['마시멜로',
#   '댄스',
#   'EDMFloor',
#   'EDM',
#   'marshmello',
#   '빌로우',
#   'marshmello',
#   '관',
#   '흥미',
#   '로운',
#   '사실',
#   '들다',
#   '!'],
#  ['봄', '설렘', '사랑', '봄', '들다', '좋다', '같다', '남돌', '노래'],
#  ['휴식',
#   '힐링',
#   '잔잔한',
#   'mbc',
#   'fm',
#   '4',
#   'u',
#   '라디오',
#   '15.01',
#   '20',
#   '화',
#   ':',
#   '천일',
#   '동안'],
#  ['휴식', '겨울감성', '연주곡', '잔잔한', '뉴에이지', '캐롤', '행복', '크리스마스', '잔잔', '연주', '곡'],
#  ['기분전환', '설렘', '사랑', '햇살', '눈', '부신', '따뜻하다', '오후', '이음', '악'],
#  ['아버지',
#   '어머니',
#   '부모님',
#   '효도',
#   '가족',
#   '어머니',
#   '아버지',
#   '가족',
#   '생각',
#   '나',
#   '늘다',
#   '가슴',
#   '뭉클하다',
#   '노래'],
#  ['나들이', '사랑', '오늘', '달달', '노래', 'vol', '11', '사랑', '해', '너', '만을'],
#  ['설렘', '사랑', '설레다', '~~~'],
#  ['겨울',
#   '출근길',
#   '월요일',
#   '월요병',
#   '지하철',
#   '드라이브',
#   '운전할때',
#   '일할때',
#   '스트레스',
#   '버스',
#   '월요일',
#   '에너지',
#   '충전',
#   '필요',
#   '때'],
#  ['사랑스러운',
#   '짜증',
#   '힐링',
#   '기분전환',
#   '사랑',
#   '스트레스',
#   '귀여운',
#   '인디',
#   '짜증',
#   '날땐',
#   '귀염',
#   '뽀짝',
#   '노래',
#   '로',
#   '!!!!'],
#  ['휴식',
#   '여행산책',
#   '인디팝',
#   '드라이브',
#   '히든트랙',
#   '꽃과벌',
#   '바우터하멜',
#   '4월1주차',
#   '주의',
#   '히든트랙',
#   ':',
#   '4월',
#   '첫째',
#   '주',
#   '바',
#   '우',
#   '터',
#   '하멜',
#   '꽃',
#   '벌',
#   '외'],
#  ['셋리스트', '공연', '2010', 'yg', 'family', 'concert', '후기'],
#  ['비오는날',
#   '나른한오후',
#   '비오는날노래',
#   '비',
#   '비내리는오후',
#   '비오는날듣기좋은노래',
#   '커피',
#   '드라이브뮤직',
#   '비오는거리',
#   '인디',
#   '비다',
#   '날'],
#  ['슬픔', '밤', '이별', '새벽', '원', '치', '않다', '이별', '로', '인하다', '아픔'],
#  ['발라드', '라디오', '394'],
#  ['댄스', '과제', '때', '듣기', '좋다', '노동요'],
#  ['새벽감성', 'RnB', '우울', 'Pop', '우울', '때', '듣다', 'pop'],
#  ['기분전환', '매장음악', '소름', '끼치다', '가창력', '!!', '소울', 'r&b'],
#  ['팝',
#   'OfficialCharts',
#   '영국',
#   'TOP20',
#   '운동',
#   'official',
#   'singleschart',
#   'top',
#   '20',
#   '171103',
#   '영국',
#   '차트'],
#  ['OST', '2012', '영화', 'ost', '다시', '듣기', '-', '보컬', '곡'],
#  ['기분전환', '까페', '더', '알려지다', '희소가치', '뮤지션', '들다', '노래'],
#  ['감성적인', '싱숭생숭', '이유', '없이', '울적', '날', '듣다', '되다', '노래', '들다'],
#  ['하루',
#   '아침',
#   '시작',
#   'sunshine',
#   'Morning',
#   '아침햇살',
#   '여행',
#   '아침',
#   '_',
#   '듣다',
#   '_',
#   '기분',
#   '좋다',
#   '_',
#   '노래'],
#  ['힐링', '휴식', '가을', '피아노', '선율', '빠져들다', '...'],
#  ['월드뮤직', 'nouvelle', 'chanson', '50'],
#  ['클래식', '노동요', '막다', '클래식'],
#  ['락', '몽환', '이끌다', '소음', 'shoegazing'],
#  ['어쿠스틱',
#   '발라드',
#   '우울',
#   '분위기',
#   '드라이브',
#   '생각',
#   '산책',
#   '운전',
#   '띵곡',
#   '인디',
#   '발라드',
#   '생각',
#   '날때',
#   '..'],
#  ['기분전환', '매장음악', '홍대', '옷가게', '에서', '나오다', '같다', '음악'],
#  ['힙합', '퓨처알앤비', '소울', '저녁드라이브', '리듬', '소울'],
#  ['감성적인', '조용한', '카페', '카페', '에서', '틀', '고', '싶다', '가사', '없다', '음악', '들다'],
#  ['록',
#   'MTV',
#   'unplugged',
#   '스쿨오브록',
#   'Rock',
#   '부활',
#   'mtv',
#   '언플러그드',
#   '그리',
#   '고',
#   '명',
#   '공연',
#   '들다',
#   'chapter',
#   '2'],
#  ['힐링', '휴식', '매장음악', '내', '가게', '틀다', '음악'],
#  ['maroon5',
#   '슈퍼볼',
#   '잡POP사전',
#   '박효재',
#   '마룬파이브',
#   '슈퍼볼',
#   'maroon',
#   '5',
#   '그리',
#   '고',
#   '기부',
#   '금'],
#  ['외로움', '새벽', '새벽녘', '마다', '찾아오다', '외로움', '달래', '감성', '짙다', '노래'],
#  ['랩', '이별', '이별', '후', '들다', '더', '공감', '되다', '힙합'],
#  ['겨울', '크리스마스'],
#  ['겨울',
#   '운동',
#   '취향저격',
#   '드라이브',
#   '여행',
#   '추천노래',
#   '힙합감성',
#   '기분전환',
#   '트렌디',
#   '신나는',
#   '이노',
#   '래',
#   '제목',
#   '뭐',
#   '야',
#   '?',
#   '되다',
#   '노래',
#   '들다'],
#  ['발라드', '사랑', '해', '요', '사랑', '해', '요', '사랑'],
#  ['트로피컬',
#   '여행',
#   '드라이브',
#   'EDM',
#   'today',
#   '#',
#   '4',
#   '올여름',
#   '마지막',
#   '휴가',
#   '트로피',
#   '컬',
#   '사운드',
#   '함께',
#   '!!'],
#  ['뉴에이지', '뉴에이지', '음악', '#.', '90', '그리움', '무지개'],
#  ['Vintage', '휴식', '기분전환', '빈티지', '레트로', '빈티', '지', '플레이', '리스트'],
#  ['힐링', '휴식', '밤', '새벽', '자기', '전', '노래', '듣다', '자다'],
#  ['뉴에이지', '사랑', '마음', '고백', '하듯', '흐르다', '뉴에이지'],
#  ['겨울', '휴식', '낭만', '여행', '설렘', '사랑', '즉흥', '휴가', '즉흥', '겨울', '겨울', '여행'],
#  ['설렘', '사랑', '내', '노래', '중', '좋다', '아하', '노래', '1'],
#  ['락', '심포닉메탈'],
#  ['여름향기',
#   '날씨',
#   '매장',
#   '여름',
#   '카페',
#   '신나다',
#   '면서',
#   '상큼',
#   '듣기',
#   '좋다',
#   '음악',
#   '모음',
#   '집',
#   'ver',
#   '2'],
#  ['감성',
#   '밤',
#   '카페',
#   '봄노래',
#   '인디팝',
#   '드라이브',
#   '봄날',
#   '밤새벽',
#   '사랑',
#   '커피숍',
#   '내',
#   '귀',
#   '사로자다',
#   '명품',
#   '감성',
#   '달콤',
#   '한보이스'],
#  ['이별', '이별극복', '이별', '힘', '드니', '?', '슬프다', '노래', '듣다', '말고', '거나', '들다'],
#  ['휴식',
#   '고급스런',
#   'Jazz',
#   '재즈',
#   '라운지',
#   '기분전환',
#   '호텔',
#   '호텔',
#   '라운지',
#   '에서',
#   '들려오다',
#   '고급',
#   '스런',
#   '재즈',
#   '음악',
#   '들다'],
#  ['운전',
#   '아이돌',
#   '걸그룹',
#   '매장',
#   '드라이브',
#   '인기',
#   '트렌디',
#   '스트레스',
#   '댄스',
#   '운동',
#   '한번',
#   '들다',
#   '계속',
#   '흥얼',
#   '거리',
#   '댄스',
#   '곡',
#   '!'],
#  ['집중',
#   '밤',
#   '연주곡',
#   '새벽감성',
#   '분위기',
#   '독서',
#   '클래식',
#   '조용한',
#   '공부',
#   '공부',
#   '때',
#   '집중',
#   '때',
#   '연주',
#   '곡',
#   '들다',
#   '나',
#   '만의',
#   '세상'],
#  ['자신감',
#   '매장음악',
#   '분위기',
#   '드라이브',
#   'Pop',
#   '기분전환',
#   '밤길',
#   '때',
#   '위풍',
#   '당당',
#   '매장',
#   '음악',
#   '꿍꽝꿍꽝'],
#  ['OST', '드라마', 'ost'],
#  ['감성',
#   '카페',
#   '오후',
#   '드라이브',
#   '저녁',
#   '기분전환',
#   '사랑',
#   '여름노래',
#   '이별',
#   '마치',
#   '내',
#   '이야기',
#   '같다',
#   '연애',
#   '단',
#   '짜다',
#   '현실',
#   '성',
#   '가사',
#   '그리',
#   '고',
#   '귀',
#   '맴도',
#   '멜로디'],
#  ['재즈피아노', '피아노', '모든따뜻한피아노', '로맨틱피아노', '눈', '내리다', '겨울', '로맨틱', '피아노', '음악'],
#  ['김영철',
#   '예능',
#   '유재석',
#   '트로트',
#   '합정역5번출구',
#   '강호동',
#   '노래방',
#   '사랑의재개발',
#   '신호등',
#   '유산슬',
#   '2019',
#   '신나다',
#   '트로트',
#   '예능',
#   '세상'],
#  ['기분전환', '운동', '통통', '튀다', '귀', '여운', '댄스', '곡', ':>'],
#  ['비오는날',
#   '감성',
#   '비',
#   '카페',
#   '사랑노래',
#   '드라이브',
#   '센치',
#   '조용한',
#   '빗소리',
#   '인디',
#   '비',
#   '오는',
#   '날',
#   '빗',
#   '소리',
#   '함께',
#   '들다',
#   '좋다',
#   '노래'],
#  ['댄스', '여름'],
#  ['휴식', '느낌있는', '비', '주말', '잔잔한', '분위기', '비', '오다', '주말', '침대', '늘어지다', '당신'],
#  ['라디오', '팝', '매장', '기분전환', '음색', '다양', '음색', '트렌디', '팝'],
#  ['투모로우바이투게더', '휴닝카이', '휴닝', '카이', '추천', '곡', '플레이', '리스트'],
#  ['락', '김정동'],
#  ['재즈', '재즈', '최신', '곡', '모음', '집', '2015년', '09월', '03일'],
#  ['개취반영',
#   '주의',
#   '살짱쿵',
#   '차트에',
#   '있는것도',
#   '포함',
#   '그루브한',
#   '※',
#   '어쩌면',
#   '주관',
#   '적',
#   '인',
#   '차트',
#   '없다',
#   '이해',
#   '안되다',
#   '팝송',
#   '※'],
#  ['힙합',
#   '한국힙합',
#   '띵곡',
#   '콜라보',
#   '외국힙합',
#   '슈프림',
#   'x',
#   '루',
#   '이비',
#   '똥',
#   '같다',
#   '명품',
#   '콜라보',
#   '히',
#   '팝',
#   '!!!!!!!'],
#  ['어쿠스틱', '아끼다', '노래'],
#  ['이별', '그리움', '후회', '이별후', '슬프다', '때', '듣다', '더', '슬프다', '노래'],
#  ['힐링', '휴식', '잔잔한', '#', '휴일', '벌써', '끝', '이야', '?', '휴일', '듯기', '좋다', '노래'],
#  ['비오는날',
#   '여름',
#   '감성',
#   '밤',
#   '여름밤',
#   '새벽',
#   '비',
#   '비다',
#   '새벽',
#   '잠',
#   '안',
#   '올',
#   '때',
#   '듣다',
#   '곡'],
#  ['팝', '기분', '기분', '따르다', '고르다', '듣다', '재미', '팝', '음악', '!', 'vol', '16'],
#  ['발라드', 'iriver', 'clix', '4'],
#  ['감성',
#   '밤',
#   '포근함',
#   '새벽',
#   '잔잔한',
#   '휴식',
#   '고요함',
#   '발라드',
#   '마음속',
#   '잔잔',
#   '함',
#   '느끼다',
#   '싶다',
#   '때',
#   '듣다',
#   '노래'],
#  ['밤', '가을', '새벽', '꼭', '밤', '들다', '알앤비', '노래', '들다', '심쿵하다'],
#  ['비오는날',
#   '잔잔한',
#   '우울',
#   '여름밤',
#   '힐링',
#   '기분전환',
#   '새벽',
#   '응답',
#   '하라',
#   '너',
#   '감성',
#   '눈물샘',
#   '자극',
#   '발라드',
#   '모음'],
#  ['드라이브', '설렘', '사랑', '본격', '잃어버리다', '연애', '세포', '찾다', '아주', '노래'],
#  ['비오는날', '밤', '새벽', 'ㅇㅇㅇㅇㅇ'],
#  ['델리민주',
#   '감각일렉',
#   '재지힙합',
#   '몽환적',
#   '▲',
#   '90',
#   '신비',
#   '우주',
#   '음악',
#   'soon',
#   'wake',
#   'up',
#   'spirits'],
#  ['조용히', '걸으며듣기좋은', '잔잔', '위로'],
#  ['휴식',
#   '아침',
#   '카페',
#   '낮잠',
#   '여유',
#   '포크',
#   '주말',
#   'Pop',
#   '감성',
#   '나른하다',
#   '주말',
#   '커피',
#   '잔',
#   '어울리다',
#   '포크',
#   '팝'],
#  ['어쿠스틱',
#   '위로가',
#   '분위기',
#   '드라이브',
#   '힐링',
#   '조용한',
#   '설렘',
#   '산책',
#   '발라드',
#   '인디',
#   '조',
#   '용한',
#   '분위기',
#   '살리다',
#   '발라드'],
#  ['힙합', '외힙', '드라이브', '알앤비', '감각', '적', '인', '힙합', '알앤비'],
#  ['힙합', '랩', '랩퍼', '힙합노래', '내', '!!!', '힙', '!!!', '합', '!!!!'],
#  ['여름', '여행', '산책', '그때', '여름밤', '꿈', '와우', '!!', '여름', '이다', '!!)'],
#  ['팝', '감미', '로운', '화음', '조화', '!', '아카펠라', '그룹'],
#  ['새벽감성', '밤', '잠이오지않는새벽', '밤', '..', '그리', '고', '새벽'],
#  ['bonOBono',
#   '처방전',
#   '연휴',
#   '아침',
#   '실룩',
#   '엉덩이',
#   '절로',
#   '실룩',
#   '늘다',
#   '연휴',
#   '아침',
#   'i',
#   '♥',
#   'long',
#   'weekend'],
#  ['느낌있는',
#   '분위기깡패',
#   '어반',
#   '알앤비',
#   '감각적인',
#   '2010년대',
#   '몽환',
#   '새벽',
#   '차',
#   '가운',
#   '새벽',
#   '몽환',
#   '감각',
#   '분위기',
#   'r&b'],
#  ['일렉', '남', '성미', '뿜어내다', '드라이브', '뮤직', 'vol', '1'],
#  ['록', '스트레스', '강제', '진압', '53'],
#  ['여행', '까페', '산책', '내', '들다', '노래', '모', '아두', '곳'],
#  ['스트레스', '기분전환', 'shuffle'],
#  ['슬픔', '밤', '이별', '새벽', '애절', '함', '뚝뚝'],
#  ['힐링', '휴식', '스트레스', '지치다', '당신', '달달', '감성', '클래식', '으랏차'],
#  ['Pop', '랜덤', '플레이', '선곡', '표'],
#  ['팝', '배철수', '음악캠프', '15년', '5월', '11일', '월'],
#  ['팝', '어', '!', '누구', '노래', '지', '?', '한번', '쯤', '들다', '보다', 'pop'],
#  ['알앤비',
#   'RNBSOUL',
#   '추억',
#   '명곡',
#   'Pop',
#   'label',
#   '레이블',
#   '경쾌한',
#   '회상',
#   '신나는',
#   '경쾌',
#   '로큰롤',
#   '소울',
#   '두왑',
#   '사운드',
#   '펼치다',
#   '보이다',
#   '레이블',
#   '카메오',
#   '-',
#   '파크',
#   '웨이'],
#  ['새벽', '혼자', '장르불문', '그냥', '혼자', '싶다', '밤'],
#  ['음추남', '발라드', '음악', '추', '천하', '남자', '음', '추남', '이다', '<', '발라드', '>'],
#  ['락', '드라이브'],
#  ['Pop', 'take', 'me', 'the', '80', 'floor', '42'],
#  ['셋리스트', '공연', '감성', '싱어송라이터', '빌리다', '코', '스티', '소극', '장', '콘서트', '!'],
#  ['봄', '이제', '봄', '❤'],
#  ['발라드', '가을', '..', '그리', '고', '옛', '발라드'],
#  ['힙합',
#   '클럽',
#   '알앤비',
#   '드라이브',
#   'Pop',
#   '외국힙합',
#   '불금',
#   '트렌디',
#   '힙존',
#   '신나는',
#   '강남',
#   '플렉스',
#   '힙존',
#   '에서',
#   '나오다',
#   '음악'],
#  ['셋리스트', '공연', '멜론', '프리미어', '-', '완전체', '귀환', '!', '씨스타', '쇼케이스', '현장'],
#  ['일렉', '▶', '일', '렉', '&', '시부야', '◀'],
#  ['산책',
#   '드라이브',
#   '여행',
#   '불쾌',
#   '지수',
#   '땅',
#   '여름',
#   '상쾌',
#   '함',
#   '주다',
#   'cool',
#   '-',
#   '뮤직',
#   '!'],
#  ['픽사', '코코', '디즈니', '<<', '디즈니', '픽사', 'o', 't', '모음', '>>'],
#  ['힙합',
#   '등등',
#   '라킴',
#   '투팍',
#   '나스',
#   '에미넴',
#   '노토리어스비아이지',
#   '최고',
#   '힙합',
#   '전설',
#   '모으다',
#   '111111'],
#  ['소울', '알앤비', '내', '좋다', '아하', '흑인음악'],
#  ['겨울',
#   '매장음악',
#   '어쿠스틱',
#   '카페',
#   '잔잔한',
#   '기분전환',
#   '인디',
#   '요즘',
#   '많이',
#   '듣다',
#   '곡',
#   '2018.2',
#   '18'],
#  ['고백', '사랑하는사람에게', '결혼식축가', '결혼식', '축가', 'best', '유스케', '나오다'],
#  ['힙합', '랩', 'oldies', '&', 'newies', '#', '3'],
#  ['재즈', '감성', '보컬', '로', '듣다', '째즈'],
#  ['비오는날', '밤', '새벽', '스피커', '볼륨', '올리다', '옆집', '에서', '욕', '안', '먹다', '곡'],
#  ['가을추천곡', '버블', '디아', '님', '!!', '추천', '곡', '!!', '28'],
#  ['비오는날', '설렘', '사랑', '첫사랑', '생', '각하', '며', '선곡'],
#  ['피아노',
#   '카페',
#   '잔잔한',
#   '추억',
#   '위로',
#   '힐링',
#   '조용한',
#   '뉴에이지',
#   '자장가',
#   '숙면',
#   '마음',
#   '위로',
#   '필요',
#   '순간',
#   '조용히',
#   '나르다',
#   '달래',
#   '주다',
#   '잔잔',
#   '뉴에이지',
#   '모음'],
#  ['비오는날',
#   '리메이크',
#   '카페',
#   '다방',
#   '챠트곡지겨움',
#   '6070',
#   '복고',
#   '궂은비',
#   '내리다',
#   '날',
#   '야말로',
#   '옛날',
#   '식',
#   '다방',
#   '멋',
#   '부리다',
#   '담',
#   '틀어주다',
#   '같다',
#   '노래'],
#  ['나만의Best3', '만우절', '피쉬슈즈', '10cm', '나', '만의', 'best', '3', ':', '10', 'cm'],
#  ['띵곡', '기분전환', '즐거운', '기분전환', '좋다', '노래', '들다', '!'],
#  ['가을밤',
#   '가을',
#   '카페',
#   '가을비',
#   '여행',
#   '바람',
#   '휴식',
#   '산책',
#   '바람',
#   '선선',
#   '가을',
#   '밤',
#   '듣기',
#   '좋다',
#   '노래'],
#  ['HipHop', 'my', 'favorite', '★', 'hiphop', '★'],
#  ['가을', '신나는', '고', '고딩', '요'],
#  ['햇살', '봄', '아침', '설렌다', '아침', '햇살', '맞다', '듣다', '설레다', '곡', '10', '선'],
#  ['여름',
#   '감성',
#   '선곡리스트',
#   '카페',
#   '잔잔한',
#   '새벽',
#   '재즈',
#   '작업',
#   '밤',
#   '카페',
#   '흐르다',
#   '부드럽다',
#   '재즈',
#   '선율',
#   '함께',
#   '정적',
#   '취하',
#   '고',
#   '싶다',
#   '하루'],
#  ['힐링', '휴식', '기분전환', '상사', '끄다', '내', '하루', '왜', '런가', '싶다'],
#  ['휴식',
#   '봄',
#   '카페',
#   '피아노연주곡모음',
#   '피아노연주곡',
#   '햇살좋은날',
#   '뉴에이지',
#   '피아노',
#   '분위기',
#   '아침',
#   '햇살',
#   '좋다',
#   '날',
#   '머리',
#   '맑다',
#   '해주',
#   '피아노',
#   '선율'],
#  ['기분좋은',
#   '카페',
#   '여유',
#   '연인',
#   '행복',
#   '고백',
#   '썸',
#   '달콤한',
#   '햇살',
#   '좋다',
#   '날',
#   '설레다',
#   '가득',
#   '러브',
#   '송'],
#  ['달달한',
#   '행복',
#   '결혼',
#   '흔하지않은',
#   '연애',
#   '고백',
#   '설렘',
#   '사랑',
#   '프로포즈',
#   '축가',
#   '흔하다',
#   '않다',
#   '고백',
#   '송',
#   '!',
#   '특별',
#   '프로포즈',
#   '세레나데',
#   '♥'],
#  ['한동윤', '다중음격', '여가수', '약진', '성장', '꾀', '솔로', '여가', '수'],
#  ['힙합',
#   'SWAG',
#   '단체곡',
#   '싸이퍼',
#   '피쳐링',
#   'HipHop',
#   '레이블',
#   '일리네어',
#   '국힙',
#   '국내',
#   '힙합',
#   '라인업',
#   '화려',
#   '단체',
#   '곡',
#   'hip',
#   'hop'],
#  ['힐링', '휴식', '기분전환', '오늘', '추천', '곡'],
#  ['감성',
#   '잔잔한',
#   '추억',
#   '출근길',
#   '인디발라드',
#   '사랑',
#   '이별',
#   '발라드',
#   '추다',
#   '요즘',
#   '많이',
#   '듣다',
#   '곡'],
#  ['추억', '회상', '80', '90'],
#  ['잔잔한', '추억', '회상', '♪', '이맘', '때', '듣다', '싶다', '곡', '♪'],
#  ['감성', '내', '스타일'],
#  ['월드',
#   '연주',
#   '재즈',
#   '탱고',
#   '집시',
#   '칸',
#   '시온',
#   '파두',
#   '...',
#   '세상',
#   '모든',
#   '음악',
#   '들다',
#   '!',
#   '83'],
#  ['발라드', '즐겁다', '하루', '^^*'],
#  ['기분전환', '여행', '홀로', '남다', '시간', '들다', '*', 'rock'],
#  ['겨울', '감성', '입동', '피아노', '겨울', '시작', '감성', '돋다', '피아노', '함께'],
#  ['드라이브', '감성', '팝송', '잔잔한', '사랑', '오빠', '랑', '같이', '들다', '노래'],
#  ['LadyGaGa',
#   '유니버설뮤직',
#   '플레이리스트',
#   '여성',
#   '솔로',
#   '팝',
#   '아티스트',
#   '대표',
#   '30',
#   '곡',
#   '모으다',
#   '!'],
#  ['감성',
#   '로맨틱',
#   '새벽',
#   '잔잔한',
#   'OST',
#   '힐링',
#   '영화',
#   '영화OST',
#   '자기전에',
#   '외국영화',
#   '잔잔',
#   '로맨스',
#   '외국',
#   '영화',
#   'ost',
#   '모음'],
#  ['클럽', '운동', '<', 'edm', '>', '2016.03', 'beatport', 'top', '100'],
#  ['기분좋은',
#   '감정',
#   '발라드',
#   '달달함',
#   '로맨스',
#   '사랑',
#   '느낌',
#   '달달',
#   '느낌',
#   '기분',
#   '좋다',
#   '아지',
#   '노래',
#   '들다',
#   '!!'],
#  ['휴식',
#   '매장음악',
#   '봄',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '센치',
#   '감성',
#   '기분전환',
#   '커피숍',
#   '잔잔',
#   '감성',
#   '노래',
#   '듣다',
#   '때'],
#  ['공룡', '키즈동요', '들썩들썩', '!', '공룡', '들다', '만나다'],
#  ['일렉', '*', '일', '렉', '크다', '럽', '운', '동', '때', '스트레스', '제로'],
#  ['집중할',
#   '회상',
#   '추억',
#   '공감',
#   '그리움',
#   '느낌있고',
#   '쓸쓸',
#   '설렘',
#   '사랑',
#   '감미로운',
#   '첫',
#   '소',
#   '절',
#   '들다',
#   '느낌',
#   '오다',
#   '곡'],
#  ['락', '라디오', '71'],
#  ['밴드',
#   'country_blues',
#   '명곡',
#   '기타',
#   '에릭클랩튼',
#   '블루스',
#   '락',
#   'legend',
#   '기타',
#   '신',
#   '에릭',
#   '클랩튼',
#   '몸',
#   '담다',
#   '밴드',
#   '들다'],
#  ['힙합', '랩', '젠', '이렇다', '노래', '홍대클럽', '에서', '않다', '틀어주다', '...'],
#  ['JPOP', '보아', '발라드', '모음', '집', 'best'],
#  ['주관주의', '개취', '첫', '소', '절', '부터', '매료', '되다', '곡'],
#  ['재즈', '노래', '로', '만나다', '재즈', '스탠더드'],
#  ['기분전환', '설렘', '사랑', '질투', '나', '네'],
#  ['락', '약', '기운', '몽롱', '국내', '사이키델릭'],
#  ['추억', '학창', '회상', '88년', '생', '싹', '~!', '다', '모여', '추억', '잠기다', '보다'],
#  ['힐링', '휴식', '그냥', '좋다', '계속', '듣다', '..'],
#  ['슬픔', '추억', '이별', '회상', '사랑', '기억', '그리', '고', '이별', '추억', '!!'],
#  ['EDM',
#   '발랄',
#   '덴스',
#   '디스코',
#   '텐션업',
#   '신나는',
#   '텐션',
#   '업',
#   '!',
#   '신나다',
#   'edm',
#   '세계',
#   '로',
#   '빠지다',
#   '보다'],
#  ['우울', '눈물', '발라드', '잔잔', '국내', '발라드'],
#  ['휴식', '힐링', '클럽', '중독', '성', '비트', '팝'],
#  ['인디', '인', '디디', '디'],
#  ['연주곡',
#   '귀여운',
#   'OST',
#   '드라마',
#   '뉴에이지곡',
#   '뉴에이지',
#   '공부',
#   '가사없는노래',
#   '들다',
#   '기분',
#   '상큼',
#   '해지',
#   '드라마',
#   '뉴에이지'],
#  ['보컬',
#   '감수성',
#   '차분한',
#   '토닥토닥',
#   '저녁',
#   '도시',
#   '밤',
#   '따뜻하다',
#   '채우다',
#   '감미',
#   '로운',
#   '보컬'],
#  ['기분전환', '드라이브', '신나다', '아침', '잠', '깨우다', 'uptown', 'punk'],
#  ['카페', '책읽을때', '♡', '책', '읽다', '때', '듣기', '좋다', '잔잔', '뉴에이지', '♡'],
#  ['스트레스', '밤', '새벽', '노을', '지는', '저녁', '들다', '좋다', '음악', '들다'],
#  ['더블로가',
#   '어이',
#   '외국힙합',
#   '행동해',
#   '해외힙합',
#   '묻고',
#   '5년동안',
#   '젊은친구',
#   '신사답게',
#   '외힙',
#   '-',
#   '외국',
#   '힙합',
#   '-',
#   '해외',
#   '힙합',
#   '5년',
#   '동안',
#   '모으다',
#   '곡',
#   '가나다순'],
#  ['어쿠스틱', '카페', '잔잔한', '새벽', '자기전에', '편안한', '기타', '소리', '함께', '보내다', '새벽'],
#  ['매장', '봄', '카페', '그루브', 'stylish', 'groove', 'up', '!!!'],
#  ['잔잔한', '감성', '아련', '새벽', '분위기', '우주', '안녕', '여기', '잊혀지다', '별', '명왕성', '이야'],
#  ['밴드',
#   'JPOP',
#   '강렬한',
#   '취향저격',
#   '록페스티벌',
#   'Rock',
#   'JRock',
#   '스트레스',
#   '제이팝',
#   '신나는',
#   'j',
#   '세계',
#   '록',
#   '시장',
#   '선',
#   '도하',
#   '일본',
#   '록',
#   '밴드',
#   '!!',
#   '#',
#   '스트레스',
#   '해소'],
#  ['1990',
#   '랩',
#   '들썩들썩',
#   '격렬함',
#   '기분전환',
#   '공격적인',
#   '분노',
#   '락',
#   '얼터너티브',
#   '스트레스해소',
#   '날카',
#   '로운',
#   '랩',
#   '강렬',
#   '하드록',
#   '동침',
#   'ratm'],
#  ['추억', '이별', '감성', '눈물', '힘내자', '내', '이별', '때', '듣다', '공감', '노래', '들다'],
#  ['여름', '기분전환', '힘겹다', '월요일', '아침', '활', '력', '넣다', '즐겁다', '음악'],
#  ['새벽', '외로움', '고독', '가을', '절망', '절망', '감', '속', '음악', 'despairs'],
#  ['비오는날',
#   '휴식',
#   '감성',
#   '집에서',
#   '침대',
#   '비오는날엔',
#   '편안한',
#   '빗',
#   '소리',
#   '함께',
#   '듣기',
#   '좋다',
#   '노래'],
#  ['나서연', '카페', '에서', '듣기', '좋다', '노래'],
#  ['일렉', '2015년', '최고', '아티스트', 'diplo', '음악', '추천', '20', '선'],
#  ['스트레스', '기분전환', '저절로', '리듬', '타다', '돼다', '★'],
#  ['완벽한', '어쿠스틱', '센티', '하고', '어쿠스틱', '오늘', '위해'],
#  ['감성캐롤', '크리스마스캐롤', '크리스마스', '캐롤', '미리', '메리크리스마스', '감성', '캐롤', '모음'],
#  ['잔잔한', '밤', '새벽', '세다', '치하', '게', '..'],
#  ['기분전환', '밤', '새벽', '요즘', 'new', '곡', '!', '느낌', '쟁이', '들다', 'swag', '❤'],
#  ['CCM', '새로운', '새', '로운', 'ccm', '들다', '어보', '기'],
#  ['추억', '기분전환', '회상', '가끔', '씩', '생각', '나', '늘다', '지난', '노래', '들다'],
#  ['발라드', '니', '네', '노래', '?'],
#  ['라운지',
#   'bar',
#   'alcoholic',
#   'Club',
#   '하우스',
#   '19금',
#   '일렉트로닉',
#   '술',
#   '음악',
#   '몽롱',
#   '취하',
#   'lounge',
#   'music',
#   'bar'],
#  ['봄', '설렘', '사랑', '알콩달콩', '달콩', '또', '알콩', '달', '콩알', '콩'],
#  ['여름',
#   '댄스',
#   '걸그룹',
#   '좋은노래',
#   '신나는',
#   '들다',
#   '더위',
#   '싹',
#   '날',
#   '라가',
#   '걸그룹',
#   '노래',
#   '모음'],
#  ['리듬', '댄스', '산책', '걸다', '면서', '리듬', '타다', '되다', '곡', '50'],
#  ['여름',
#   '감성',
#   '상큼한',
#   '아이돌',
#   '상쾌',
#   '힐링',
#   '기분전환',
#   '설렘',
#   '사랑',
#   '여름',
#   '듣기',
#   '좋다',
#   '달달',
#   '아이돌',
#   '노래'],
#  ['밴드', '우울', '위로', '공감', '슬픔', '인디', '울', '고', '싶다', '날', '듣다', '노래'],
#  ['소울', '알앤비', '미니홈피', '컬러링', 'bgm', '로', '깔다', '좋다', '같다', '캐롤'],
#  ['봄',
#   '운동',
#   '감각적인',
#   '드라이브',
#   '그루브',
#   '기분전환',
#   '리드미컬',
#   '여행',
#   '힙스터',
#   '신나는',
#   '드라이브',
#   '좋다',
#   '날씨',
#   '트렌디',
#   '사운드'],
#  ['클래식', '편안', '휴식', '아름', '다운', '피아노', '연주', '곡', '-', '클래식'],
#  ['내가좋아하는곡들', '그냥', '내', '좋다', '아하', '노래'],
#  ['신나고', 'AlanWalker', '일렉트로니카', '신나다', 'alan', 'walker', '음악', '!'],
#  ['슬픔', '잔잔한', '이별', '발라드', '잠들다', '기전', 'playlist'],
#  ['인디', '낡다', '배낭', '메다', '여행'],
#  ['JPOP', '좋나좋쿤', '??'],
#  ['뉴에이지', '매장', '아름', '답', '게', '뉴에이지', '음악'],
#  ['힙합',
#   '집중',
#   '잔잔한',
#   '시험',
#   '수능',
#   '독서',
#   '해외랩힙합',
#   '비트',
#   'Lofi',
#   '공부',
#   '몰입도',
#   'up',
#   '!',
#   '집중',
#   'lo',
#   '-',
#   'fi',
#   'bgm'],
#  ['분위기있는', '기분전환', '산책', '산책', '때', '듣기', '좋다', '곡'],
#  ['여행', '추억', '산책', '회상', '손', '성애자', '들다', '위해', '준비'],
#  ['겨울',
#   '감성',
#   '카페',
#   '잔잔한',
#   '발라드',
#   '커피',
#   '기분전환',
#   '사랑',
#   '요즘',
#   '듣다',
#   '발라드',
#   '1.2'],
#  ['기분전환', '신나다', '노래', '다가', '지다', '오다', '~~~!'],
#  ['힐링', '휴식', '기분전환', '삶', '지치다', '당신', '만을', '응원', '곡'],
#  ['감성',
#   '봄',
#   '아침',
#   '봄비',
#   'Jazz',
#   '재즈',
#   '기분전환',
#   '사랑',
#   '낭만적인',
#   '까페',
#   '봄비',
#   '맞다',
#   '듣다',
#   '낭',
#   '만적',
#   '인',
#   'jazz'],
#  ['추억', '사랑', '설렘', '회상', '깊다', '강렬', '감동', '주다', '곡', 'top', '5'],
#  ['슬픔', '추억', '이별', '회상', 'dj', '또릿', '이별', '관련', '보물', '같다', '노래'],
#  ['댄스', 'hon', '_', 'style', 'ⅰ', 'dance'],
#  ['음색좋은',
#   '감성자극',
#   '숨겨진노래',
#   '기타곡',
#   '보컬솔로',
#   '사랑',
#   '기타연주',
#   '기타솔로',
#   '아름다워',
#   '기타',
#   '솔로',
#   '감미',
#   '로운',
#   '보컬',
#   '만난',
#   '플레이',
#   '리스트'],
#  ['듣기편한', '듣다', '곡'],
#  ['댄스', 'god', '15', '주년', '앵콜', '콘서트', '셋', '리스트'],
#  ['까페', '설렘', '사랑', '따스하다', '봄', '사탕', '처럼', '달달', '노래'],
#  ['힐링', '휴식', '기분전환', '캬', '행복', '기운', '불어', '넣다', '싱그럽다', '음악', '♡'],
#  ['오늘의감성', '오늘의분위기', '노동요', '감성음악', '지칠때', '듣기좋은', '오늘', '분위기'],
#  ['발라드', 'un', '믹스', '판'],
#  ['취향저격', '최신팝', '심쿵', '차트', '차트', '곡', '들다', '무슨', '재민', '겨', '??'],
#  ['일렉', '강하다', '클럽', '음악'],
#  ['휴식',
#   '매장음악',
#   '봄',
#   '여유',
#   '잔잔한',
#   '취향저격',
#   '오후',
#   '커피',
#   '감성',
#   '기분전환',
#   '커피한잔',
#   '여유',
#   '도와주다',
#   '보이스'],
#  ['애드나인프로젝트', '팝', '이지', '리스닝', '뮤지션', '애드', '나인', '프로젝트', '전곡', '듣기'],
#  ['새벽감성', '잔잔한', '새벽', 'alone'],
#  ['아이돌수록곡',
#   '아이돌',
#   '잔잔한',
#   '명곡',
#   '숨은띵곡',
#   '수록곡',
#   '신나는',
#   '나',
#   '까운',
#   '<',
#   '아이돌',
#   '숨다',
#   '명곡',
#   '모음',
#   '>',
#   '*',
#   '수록',
#   '곡',
#   '위주'],
#  ['겨울',
#   '가을',
#   '발라드',
#   '알앤비',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '드라이브',
#   '하',
#   '면서',
#   '듣기',
#   '좋다',
#   '곡',
#   '모음'],
#  ['가을', '지난', '가을', '회', '상하', '며', '음악', '잠기', '다', '..'],
#  ['스트레스', '밤', '새벽', '자다', '들다', '밤', '잡', '생각', '정화', '피아노', '음악'],
#  ['비오는날',
#   '감성힙합',
#   '듣기좋은',
#   '새벽',
#   '새벽감성',
#   '매력있는',
#   '분위기',
#   '팝',
#   '한번',
#   '들다',
#   '빠지다',
#   '수',
#   '밖에',
#   '없다',
#   '껄',
#   '?',
#   '마',
#   '성의',
#   '매력',
#   '지니다',
#   '곡'],
#  ['인디', 'like'],
#  ['AOA', '테스트', '7'],
#  ['댄스', '즐겁다', '하루', '하루'],
#  ['감각적인',
#   'Pop',
#   '감각적',
#   '그루브있는',
#   '팝',
#   '신나는',
#   '도입',
#   '부터',
#   '느낌',
#   '오다',
#   '감각',
#   '적',
#   '인',
#   '팝'],
#  ['매장음악', '까페', '냉장고', '부탁', '해', '30회', 'bgm'],
#  ['추억', '사랑', '설렘', '회상', '가다', '수바', '라기', 'no', '83', 'e', '베스트', '20'],
#  ['처음들어도좋은곡들', '팝송', '소울', '알앤비', '처음', '듣다', '지만', '낯설다', '않다', '알앤비', '소울'],
#  ['이별', '감성', '사랑', '아프다', '사랑', '일지', '라도', '사랑', '그리', '운', '이를', '위로'],
#  ['감성', '드라이브', '크리스마스', '234'],
#  ['까페',
#   '잔잔한',
#   '이루마',
#   '베스트',
#   '!',
#   '오다',
#   '2015년',
#   '눈에뛰는',
#   '뉴에이지',
#   '아티스트',
#   '들다',
#   '!'],
#  ['휴식',
#   '혼자',
#   '새벽',
#   '추억',
#   '그리움',
#   '감성',
#   '사랑',
#   '회상',
#   '분위기',
#   '깊다',
#   '밤',
#   '누군가',
#   '그리',
#   '운',
#   '시간',
#   '..'],
#  ['피크닉',
#   '휴양지',
#   '드라이브',
#   'timeoff',
#   'Pop',
#   '여행',
#   '바람',
#   '기분전환',
#   '외출',
#   '초여름',
#   '테라스',
#   '앉다',
#   '모히또',
#   '잔',
#   '함께',
#   '시원',
#   '바람',
#   '맞다',
#   '듣다',
#   'music'],
#  ['힙합', '랩', '랩', '보컬', '콜라보', ':)'],
#  ['댄스', '태티서', '12', '부터', '15', '까지'],
#  ['이별노래', '눈물', '그리움', '@', '슬프다', '이별', '들다', '노래', '@'],
#  ['OST', '썸', '영화', '러브', '로지', 'ost'],
#  ['퇴근',
#   '어쿠스틱',
#   '여유',
#   '잔잔한',
#   '이어폰',
#   '겨울',
#   '멜로디',
#   '늦은밤',
#   '쓸쓸함',
#   '밤',
#   '밤',
#   '거리',
#   '거닐다',
#   '이어폰',
#   '끼',
#   '고',
#   '듣기',
#   '좋다',
#   '노래'],
#  ['잔잔한',
#   '감성적인',
#   '힐링',
#   '가을',
#   '노래들',
#   '가을',
#   '이라',
#   '더',
#   '감성',
#   '돋다',
#   '들다',
#   '수록',
#   '좋다',
#   '노래',
#   '들다',
#   '~!!'],
#  ['비오는날', '감성', '추억', '발라드', '가을', '잠기', '고', '플', '때', '버스', '에서'],
#  ['Tiesto',
#   '여름',
#   '일렉트로니카',
#   'Odesza',
#   'SanHolo',
#   'Kygo',
#   'Matoma',
#   '드라이브',
#   'AVICII',
#   'Kshmr',
#   '드라이브',
#   '진미',
#   '느끼다',
#   '수',
#   '청량하다',
#   '대표',
#   'edm',
#   '들다',
#   '소개',
#   '!'],
#  ['크리스마스캐롤', '캐롤동요', '크리스마스', '캐롤', '동요'],
#  ['BJ금복남', '외로움', '밤', '듣다', '음악'],
#  ['째즈',
#   '휴식',
#   '주말',
#   '오후',
#   'Jazz',
#   '재즈',
#   '커피',
#   '피아노',
#   '나른하다',
#   '쉬',
#   '고',
#   '싶다',
#   '때',
#   '듣다',
#   '재즈',
#   '곡'],
#  ['힙합',
#   '인생이힘들때',
#   '랩',
#   '힙찔이',
#   '국내힙합',
#   '외국힙합',
#   'HipHop',
#   '외힙',
#   'Rap',
#   '국힙',
#   '힙찐이',
#   '베리',
#   '!!',
#   '매우',
#   '추',
#   '천하',
#   '힙합',
#   '곡',
#   '50',
#   '선',
#   '!!'],
#  ['발라드', '행복'],
#  ['electronica', '빌로우', 'EDM', '신나는', '9월', '최신', '일렉트로닉', '음악', '소식'],
#  ['잔잔한',
#   '회상',
#   '추억',
#   '슬픔',
#   '설렘',
#   '이별',
#   '쓸쓸함',
#   '지나',
#   '간',
#   '추억',
#   '생',
#   '각하',
#   '며',
#   '듣다',
#   '감성',
#   '노래'],
#  ['2017가요명곡', '2017', '놓치지마세요', '띵곡', '놓치다', '말다', '!', '2017년', '가요', '명곡'],
#  ['여름',
#   '청량',
#   'YOLO',
#   '드라이브',
#   '여행',
#   '팝',
#   '시원한',
#   '기분전환',
#   '스트레스',
#   'COOL',
#   '시원',
#   '하고',
#   '청량하다',
#   'music',
#   'cover',
#   'design'],
#  ['댄스', '추억'],
#  ['팝', '시원', '가을', '이렇다', '음악', '어떻다', '?'],
#  ['락', '신나다', '락', '음악', '9'],
#  ['하성운', '워너원', '성운', '행복', '해주다', '하늘', '믿다', '?'],
#  ['힐링', '휴식', '추억', '회상', '가을', '끝', '겨울', '시작'],
#  ['뉴에이지', '연휴', '후유증', '잠재', '워줄', '평화로', '운', '뉴에이지'],
#  ['산책', '여행', '잔잔한', '마음', '차', '분해', '지는', '듣기', '좋다', '뉴에이지'],
#  ['힙합', '랩', '한번', '들다', '중독', '되다', '힙합', '곡', 'list', '!'],
#  ['댄스', '초딩', '시절'],
#  ['클럽', '스트레스', 'edm', 'musixxxxxx'],
#  ['추억', '회상', '연말', '연', '시', '듣기', '좋다', '노래', '들다'],
#  ['클래식', '세상', '매료', '시키다', '천사', '목소리', 'libera'],
#  ['glamrock',
#   '벨벳골드마인',
#   '벨벳골드마인OST',
#   'VELVETGOLDMINE',
#   '글램록',
#   '영화',
#   '벨벳',
#   '골드',
#   '마인',
#   'ost',
#   '영화',
#   '등장',
#   '순',
#   '삽입곡',
#   '원',
#   '곡'],
#  ['클래식', '시험', '공부', '함께', '-', '★'],
#  ['Flex',
#   '여름',
#   '클럽',
#   '국내힙합',
#   '2019',
#   '국내인디음악',
#   '더위',
#   '트렌디',
#   '인디',
#   '2019',
#   '당신',
#   '여름',
#   '채우다',
#   '국내',
#   '힙합',
#   '이다',
#   '힙합',
#   '104',
#   '선곡'],
#  ['달달', '설레임', '연애', '좋은', '사랑', '달달', '노래'],
#  ['힙합', '힙합', '아이돌', '전해', '라', '522'],
#  ['스트레스', '기분전환', '화', '식히다', '힐링', '클래식'],
#  ['여름', '무덥다', '여름', '들다', '시원', '해지', '노래'],
#  ['소울', '알앤비', '빌보드', '2008년', '싱글차트', '20'],
#  ['슬픔', '이별', '발라드', '모음', '집', '슬프다', '노래', '듣다', '싶다', '때'],
#  ['마법사',
#   '음악',
#   '판타지',
#   '요정',
#   '호빗',
#   '금방',
#   '이라도',
#   '호빗',
#   '마법사',
#   '튀어',
#   '나',
#   '오다',
#   '같다',
#   '판타지',
#   '클래식'],
#  ['가을', '가을비', '오다'],
#  ['락', '아트', '마감', '송', '1'],
#  ['여행', '사랑', '설렘', '산책', '사랑', '하오'],
#  ['드라마', '명곡', '영화', 'OST', '장면', '생각', '나', '늘다', '드라마', 'ost', '✨'],
#  ['발라드', '가을', '밤', '내', '듣다', '싶다', '노래'],
#  ['일렉', '놓다', '치기', '너무', '까운', '재즈', '&', '팝', '컬렉션'],
#  ['락', '신나다', '깔끔하다', '음악', '들다', '!'],
#  ['힐링', '휴식', '겨울', '눈', '오는', '날', '굿', '멜로디'],
#  ['영화음악',
#   '영화삽입곡',
#   '노동요',
#   'OST',
#   '테마곡',
#   '기억',
#   '남다',
#   '다시',
#   '또',
#   '듣다',
#   '싶다',
#   '영화',
#   'ost'],
#  ['추억', '회상', '너무', '우울', '해', '정말'],
#  ['겨울',
#   '휴식',
#   '카페',
#   '가을',
#   '드라이브',
#   '감성',
#   '너',
#   '같이',
#   '들다',
#   '슬프다',
#   '않다',
#   '노래',
#   'list'],
#  ['사랑', '그녀', '불다', '고프다', '팝'],
#  ['겨울',
#   '휴식',
#   '밤',
#   '발라드',
#   '새벽',
#   '인디',
#   '감성충전',
#   '이불',
#   '쓸쓸할때',
#   '따뜻한',
#   '혼자',
#   '만의',
#   '시간',
#   '함께',
#   '잔잔',
#   '발라드'],
#  ['소울', '알앤비', '상수역', '☆', '까페', '거리', '＃', '감성', '음악'],
#  ['일렉', '열'],
#  ['비오는날',
#   '감성',
#   '잔잔한',
#   '새벽감성',
#   '우울',
#   '발라드',
#   '재즈',
#   '슬픔',
#   '자장가',
#   '인디',
#   '흐리다',
#   '날',
#   '울적',
#   '내',
#   '마음',
#   '같다',
#   '노래'],
#  ['힐링',
#   '휴식',
#   '기분전환',
#   '《《',
#   '뜻',
#   '밖',
#   '취향',
#   '저격',
#   'sm',
#   '가수',
#   '들다',
#   '좋다',
#   '노래',
#   '들다',
#   '》》'],
#  ['라운지음악',
#   '오빠이노래뭐야',
#   '드라이브',
#   '감성일렉',
#   '이태원',
#   '기분전환',
#   '너만몰라',
#   '#',
#   '라운지',
#   '필청',
#   '뮤직',
#   '#'],
#  ['팝', '겨울왕국', '노르웨이', '감성', '팝'],
#  ['기분전환', '설렘', '사랑', '❤', '달달', '❤'],
#  ['뉴에이지', '들다', '수록', '매력', '적', '섬세', '뉴에이지', '음악', '세계', '로'],
#  ['힐링', '휴식', '기분전환', '빅뱅', '사랑', '해', '요', '데뷔', '한지', '이제', '약', '9년', '인'],
#  ['감성', '작업', 'when', 'i', 'work', ':'],
#  ['카페음악',
#   '숨은명곡',
#   '분위기있는_인디음악',
#   '추천곡',
#   '카페',
#   '자다',
#   '어울리다',
#   '분위기',
#   '어쿠스틱',
#   '인디음악',
#   '-'],
#  ['휴식', '힐링', '잔잔한', '듣기', '편하다', '음악', '모음'],
#  ['잔잔한', '밤', '새벽', '잔잔', '바람', '함께', '듣다', '노래'],
#  ['휴식', '카페', '고독', '드라이브', '브릿팝', '힐링', '기분전환', '데이트', '여행', '모던락', 'gray'],
#  ['랜덤', '장르파괴', '이유', '없이', '좋다', '음악', '장르', '가다', '리지', '않다', '클릭'],
#  ['클럽', '매장음악', 'remix', '여서', '더', '듣기', '좋다', 'black', 'music', '모음', ':)'],
#  ['설레임', '봄', '설렘', '추천', '♬', '그대', '나', '설레임'],
#  ['힐링', '휴식', '까페', '기분', '좋다', '음악', '들다', '면서', '커피한잔', '여유', '시간'],
#  ['발라드', '사랑', '이란', '?', '관심', '!'],
#  ['스트레스', '기분전환', '아침', '출근길', '등교', '길', '힘', '빠샤빠샤', '!!!'],
#  ['소울', '알앤비', '잡', '살다', '2'],
#  ['매장음악', '잔잔한', '잔잔', '듣기', '좋다', '매장', '피아노', '음악', '..'],
#  ['스트레스', '감성', '기분전환', '잔잔한', '잠', '안', '오다', '때', '듣다', '클래식', '평온', '함'],
#  ['팝송추천', '사랑설렘', '감성', '자극', '팝', '노래', '!!'],
#  ['드라이브', 'rudominick', '여행', '부산', 'dominick', '드라이빙', '도미니크', '부산', '늘다'],
#  ['발라드', '★', '햇반', '_', '2011년', '듣다', '가요'],
#  ['활기찬',
#   'CCM',
#   '운동할때듣는',
#   '찬양',
#   '신나는ccm',
#   '빠른',
#   'ThankYouLord',
#   '힘내',
#   '#',
#   '운동',
#   '때',
#   '듣다',
#   '신나다',
#   '찬양'],
#  ['팝', '흑백', '앨범', '속', '감추다', '숨다', '명곡', 'best'],
#  ['가사가좋은노래', '멍할때', '생각', '없이', '들다', '더', '좋다', '노래'],
#  ['랩', '스트레스', 'HipHop', '기분전환', 'Rap', '속', '천', '불', '이난', '다'],
#  ['겨울', '감성', '출근길', '기분전환', '퇴근길', '스트레스', '산뜻하다', '출퇴근', '송'],
#  ['히사이시조',
#   '지브리',
#   '센과치이로의행방불명',
#   '인생의회전목마',
#   '미야자키하야오',
#   '지브리',
#   '스튜디오',
#   '전곡',
#   '듣기'],
#  ['감성',
#   '느낌있는',
#   '취향저격',
#   '드라이브',
#   '추천노래',
#   '팝송',
#   '기분전환',
#   '띵곡',
#   '최애곡',
#   '신나는',
#   '<',
#   '너',
#   '최애',
#   '팝송',
#   '되다',
#   '싶다',
#   '>'],
#  ['재즈', '▲', '릴렉싱', '보사노바'],
#  ['힙합', '노래', '분위기', '알엔비', '모든', '곳', '어울리다', '노래'],
#  ['매장음악',
#   '카페',
#   '잔잔한',
#   '러블리쏘',
#   '분위기',
#   'OST',
#   '드라마',
#   '설렘',
#   '사랑',
#   '팝',
#   '드라마',
#   '속',
#   '분위기',
#   '녹다',
#   '들다',
#   'pop',
#   'pt',
#   '3'],
#  ['슬픔', '이별', '잔잔한', '가슴', '아프다', '그렇다', '이야기'],
#  ['휴식',
#   '힐링',
#   '여행',
#   '산책',
#   '절대',
#   '놓치다',
#   '서다',
#   '안되다',
#   '이다',
#   '뮤지션',
#   '15',
#   '인',
#   'vol',
#   '1'],
#  ['33분',
#   '베스트11',
#   'Pop',
#   '<',
#   '33분',
#   'pop',
#   '플레이',
#   '리스트',
#   '>',
#   '#',
#   '3',
#   'dj',
#   '가다',
#   '추',
#   '천하',
#   '소장',
#   '필수',
#   '곡'],
#  ['클럽',
#   '매장음악',
#   '카페',
#   '새벽',
#   '댄스',
#   '분위기',
#   '드라이브',
#   '감성',
#   '섹시',
#   '끈적',
#   '끈적끈적하다',
#   '플레이',
#   '리스트'],
#  ['버스',
#   '멜로우',
#   '드라이브',
#   '그루브',
#   '가족',
#   '기분전환',
#   '재즈힙합',
#   '여행',
#   '운전',
#   '차안',
#   '에서',
#   '듣다',
#   '드라이브',
#   '음악'],
#  ['슬픔', '이별', '설렘', '사랑', '완전', '좋다', '..'],
#  ['일렉', '씨', '어', '터', '카페', '2015', 'ss'],
#  ['OST', '상상력', '북', '돋다', '아주', '음악', '들다'],
#  ['비오는날', '명곡', '지아', 'zia', '비', '오는', '날', '지아'],
#  ['팝', 'solitude'],
#  ['카페음악',
#   '카페',
#   '명곡',
#   '컨트리',
#   'Blues',
#   '블루스',
#   '커피',
#   '말다',
#   '면서',
#   '즐기다',
#   '블루스',
#   '&',
#   '컨트리송',
#   ':)'],
#  ['프로그레시브', '락', '명곡들', '재즈', '재즈', '풍', '프로그레시브', '락', '명곡', '들다'],
#  ['잔잔한', '밤', '새벽', '새벽', '듣기', '좋다', '노래', '들다', '2'],
#  ['이별', '발라드', '슬픈', '눈물', '사랑', '발라드', '노래', '모음곡'],
#  ['발라드', '겨울', '이면', '더욱', '듣다', '슬프다', '노래', '♪'],
#  ['휴식', '밤', '새벽', '잔잔', '그루브', '힐링', '기분전환', '요즘', '쫌', '땡기다', '음악'],
#  ['고막남친',
#   '감성',
#   '밤산책',
#   '밤에듣기좋은노래',
#   '부드러운',
#   '고막여친',
#   '음색깡패',
#   '번',
#   '들다',
#   '빠져들다',
#   '수',
#   '밖에',
#   '없다',
#   '부드럽다',
#   '음색'],
#  ['잔잔한', 'indie', '인디음악', 'indies', '인디뮤직', '인디', '잔잔', '인디음악', '모음'],
#  ['힙합', '랩', 'vmc', '늘다', '어떻다', '?'],
#  ['잔잔',
#   '분위기',
#   '음악',
#   '카페',
#   '한적',
#   '한적',
#   '날',
#   '카페',
#   '에서',
#   '듣기',
#   '좋다',
#   '음악',
#   '들다',
#   '해외',
#   'ver',
#   '#',
#   '1'],
#  ['졸음', '나른한', '나른하다', '오후', '딱이다', '노래', 'ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ'],
#  ['락', '내', '선정', '클럽', '노래', '!'],
#  ['잔잔한', '위로', '감성', '기분전환', '신나는', '위로', '받다', '싶다', '때', '듣다', '노래'],
#  ['박주연', 'M에센셜', 'ballad', '작사가', '발라드', '발라드', 'lyrics', 'by', '박주연'],
#  ['락', '슬픔', '흥분', '그리', '고', '기쁨'],
#  ['락', '신해철', 'rock', 'opera', 'prototype', '1'],
#  ['감성',
#   '휴일',
#   '울적',
#   '팝송',
#   '비',
#   '비다',
#   '울적',
#   '휴일',
#   '당신',
#   '감성',
#   '폭발',
#   '시키다',
#   '음악',
#   '들다'],
#  ['감성',
#   '가을',
#   '잔잔한',
#   '스트레스',
#   '여행',
#   '드리이브',
#   '낙엽',
#   '드라이브곡',
#   '드라이브',
#   '때',
#   '듣기',
#   '좋다',
#   '노래',
#   '들다',
#   '추천'],
#  ['포크',
#   '내가좋아하는음악트랙',
#   '노래추천',
#   '인디추천',
#   '이달의인디포크',
#   '음악추천',
#   '인디',
#   '달',
#   '이다',
#   '·',
#   '포크',
#   '2018년',
#   '06월'],
#  ['복면가왕', '복면', '왕', '137회', '18.01', '21'],
#  ['보석함',
#   '기분전환',
#   '드라이브',
#   '봄',
#   '산책',
#   '장르',
#   '불문',
#   '보석',
#   '함',
#   '간직',
#   '나',
#   '고',
#   '싶다',
#   '곡'],
#  ['잔잔한', '설렘', '사랑', '감', '성적', '인', '멜로디', '음악', '♥'],
#  ['애즈원',
#   '응답하라',
#   '그때',
#   '회상',
#   '추억',
#   'OST',
#   '드라마',
#   '기분전환',
#   '2000년대',
#   '추억',
#   '새록새록',
#   '-',
#   '2000',
#   '년대',
#   '드라마',
#   'ost'],
#  ['힙합', '랩', '감성', '힙합', '스탈'],
#  ['팝', '〃', '멜로디', '예쁘다', 'pop', '〃'],
#  ['감성',
#   '카페',
#   '새벽',
#   '달달',
#   '야경',
#   '꿀성대',
#   '휴식',
#   '뉴에이지',
#   '사랑',
#   '잔잔',
#   '잔잔',
#   '혹은',
#   '달달',
#   '밤',
#   '음악',
#   ':)'],
#  ['추억', '기분전환', '회상', '산다', '게', '다', '그렇다', '아니', '겠다', '?'],
#  ['힙합', '감성', '어쿠스틱', '새벽', 'RnB', '사랑', '인디', '새벽', '한번', '들다', '보다'],
#  ['노래방', '추억', '리메이크', '친근한', '회상', '리메이크', '또', '다른', '느낌'],
#  ['연말',
#   '따스한',
#   '겨울송',
#   '성탄절',
#   '멜로디',
#   '산타클로스',
#   '미리메리크리스마스',
#   '캐롤',
#   '메리',
#   '크리스마스',
#   '베',
#   '리베리',
#   '퍼펙트',
#   '팝',
#   '캐롤',
#   '선물',
#   '세트',
#   '오다',
#   '♥'],
#  ['소울', '알앤비', 'secret', 'garden', 'part', '1'],
#  ['배경음악',
#   'OST',
#   '뉴에이지',
#   'bgm',
#   '영상편집',
#   '가사없는노래',
#   'inst',
#   'ost',
#   '가요',
#   '좋다',
#   'inst',
#   '모음'],
#  ['경쾌한음악',
#   '여름',
#   '신나는음악',
#   '청량한음악',
#   '재즈',
#   '기분전환',
#   '습',
#   '하고',
#   '덥다',
#   '날',
#   '상쾌',
#   '재즈',
#   '로',
#   '기분전환',
#   '!'],
#  ['스크랴빈',
#   '프로코피예프',
#   '러시아클래식',
#   '라흐마니노프',
#   '러시아',
#   '덥다',
#   '여름철',
#   '듣기',
#   '좋다',
#   '러시아',
#   '클래식'],
#  ['겨울',
#   '감성',
#   '가을',
#   '아침',
#   '잔잔한',
#   'Jazz',
#   '명곡',
#   '기분전환',
#   '작업',
#   '재즈곡',
#   '명쾌',
#   '발상',
#   'jazzy',
#   '상상'],
#  ['아무거나', '친구', '추천'],
#  ['슬픔', '추억', '이별', '회상', '사랑', '추억', '떠올리다', '노래'],
#  ['여름', '여름클래식', '계절', '여름을주제로한클래식', '여름', '주제', '로', '클래식', '음악', '모음'],
#  ['뉴에이지', '토닥토닥', '..', '당신', '마음', '위로', '뉴에이지', '피아노', '연주', '곡'],
#  ['일렉', '클럽', 'panfic', 'music', 'festival', 'no', '10'],
#  ['겨울', '설렘', '사랑', '♣', '마음', '설', '레이', '게', '좋다', 'music', ':)'],
#  ['밴드', '감성', '락', '락발라드', '시대', '풍', '밉다', '감성', '밴드'],
#  ['Pop', '고인물', '사실', '상', '요즘', '내', '마음속', 'pop', '고인', '물'],
#  ['팝', '벚꽃', '함께', '찾다', '싶다', '지는', '달달', '노래'],
#  ['비오는날',
#   '감성힙합',
#   '여름밤',
#   '추억',
#   '국내힙합',
#   '가사',
#   '방황',
#   '감성',
#   '청춘',
#   '새벽',
#   '도돌이표',
#   '누르다',
#   '찍다',
#   '청춘',
#   '불협화음'],
#  ['감성',
#   '듣기좋은',
#   '봄',
#   '카페',
#   '잔잔한',
#   '분위기',
#   '커피',
#   '따스한',
#   '혼자',
#   '발라드',
#   '잔잔',
#   '노래',
#   '그리',
#   '고',
#   '커피한잔',
#   '어떻다',
#   '?'],
#  ['디즈니OST',
#   'OST',
#   '애니메이션',
#   '디즈니',
#   '픽사',
#   '애니메이션OST',
#   '디즈니',
#   '&',
#   '픽사',
#   '애니메이션',
#   'ost'],
#  ['추억', '회상', '8090', '우리', '음악', '지배', '때'],
#  ['발라드', '라디오', '676'],
#  ['힐링', '기분전환', '봄', '재즈', '감성', '넘치다', '소울재즈', '매력'],
#  ['발라드', '아이유', '기분전환', '사랑', '락', '신나는', '아가', '수', '이지은', '갓띵곡', '모음'],
#  ['RnB', '트렌드', '세터', '업타운', '펑크', '!', '350'],
#  ['락', 'r', 'o', 'c', 'k', 'm', 'u', 'i', 'c', '명곡', '모음', '-', '2'],
#  ['슬픔', '이별', '설렘', '사랑', '_', '위로', '해', '주다', '~_'],
#  ['비오는날', '추억', '회상', '비', '가내', '리', '고', '음악', '..'],
#  ['신나는_음악',
#   '운동_할_때',
#   '달리기',
#   '운동하자',
#   '기분전환',
#   '팝송모음',
#   '운동할때듣는음악',
#   '운동',
#   '운동',
#   '때',
#   '듣다',
#   '팝송'],
#  ['스트레스', '기분전환', '무한', '반복', '되다', '나', '만의', '완소', '곡'],
#  ['이국적인_팝송',
#   '매장음악',
#   '운동할때',
#   '최신',
#   '댄스음악',
#   '신나는',
#   '몸',
#   '흔들다',
#   '흔들다',
#   '신나다',
#   '국적',
#   '인',
#   '팝송',
#   '모음',
#   '!'],
#  ['비트좋은',
#   '감성힙합',
#   '느낌있는',
#   '스웩',
#   '분위기',
#   '드라이브',
#   '기분전환',
#   '유니크',
#   '리드미컬',
#   '트렌디',
#   '드라이브',
#   '딱',
#   '좋다',
#   '봄날',
#   '트렌디',
#   '달다',
#   '보다'],
#  ['감각적인', '니', '들어주다', '음악', '!'],
#  ['발라드', '윤현'],
#  ['일렉', '운동', '신나는', '운동', '때', '흥', '돋다', '해주', '신나다', '노래', '들다'],
#  ['락', '심장', '고', '동치', '첼로', '연주', '-', 'pop', '&', 'rock'],
#  ['슬픔', '추억', '이별', '회상', '푸른', '바다', '女人', '이별', '노래', '..', '#', '2'],
#  ['휴식',
#   '힐링',
#   '여행',
#   '산책',
#   '훌쩍',
#   '떠나다',
#   '버리다',
#   '고프다',
#   '본격',
#   '휴양지',
#   '최적화',
#   '음악',
#   '!'],
#  ['실음과', '동아방송예술대학교', '실용음악과', '동아방송예술대학교', '실음', '뮤지션', '들다', '음악'],
#  ['운동',
#   '미국',
#   'TOP20',
#   'Hot100',
#   'Billboard',
#   '팝',
#   'billboard',
#   'thehot',
#   '100',
#   'top',
#   '20',
#   '170923',
#   '미국',
#   '차트'],
#  ['청량감', 'Pop', '탄산음료', '말다', '듯', '청량하다', '느낌', '노래', '#pop'],
#  ['슬픔',
#   '추억',
#   '이별',
#   '회상',
#   '나',
#   '한테',
#   '늘다',
#   '없다',
#   '감정',
#   '들다',
#   '생기',
#   '게',
#   '같다',
#   '감성',
#   '돋다',
#   '음악',
#   '들다'],
#  ['까페', '설렘', '사랑', '달달', '하고', '감', '성적', '인', '이다', '듀엣곡'],
#  ['느낌있는',
#   'Bass',
#   '노동요',
#   'EDM',
#   'Electonica',
#   'Electronic',
#   '일렉',
#   '지하',
#   '에서',
#   '울리다',
#   '지는',
#   '사운드',
#   '내려가다',
#   '보다',
#   '::',
#   'current',
#   'mood'],
#  ['힙합',
#   'DJ_JASON',
#   '힙선남',
#   'DJJASON',
#   'HipHop',
#   'KOREAN_HIPHOP',
#   'DJ제이슨',
#   '한국힙합',
#   '음악추천',
#   '힙합을선곡하는남자',
#   '플로우',
#   '기',
#   '막히다',
#   '힙합'],
#  ['스트레스', '기분전환', '비트', '몸', '맡다', '기고'],
#  ['소울', '알앤비', 'jazzy', '&', 'soul'],
#  ['클래식', '클래식', '최신', '곡', '모음', '집', '2014년', '10월', '02일'],
#  ['달달', '달콤', '설렘', '달콤하다', '말', '랑', '감성', '설레다', '노래', '들다'],
#  ['감성',
#   '나른나른',
#   '봄',
#   '락',
#   '날씨',
#   '햇살',
#   'Chillout',
#   '팝',
#   '인디',
#   '나르다',
#   '나른하다',
#   '목소리',
#   '취해',
#   '봄',
#   '어울리다',
#   'chill',
#   'out',
#   '음악',
#   '리스트'],
#  ['슬픔', '추억', '이별', '회상', '사랑', '후'],
#  ['카페', '사랑', '드라이브', '공원', '고백', '기분전환', '산책', '오늘', '달달', '노래', 'vol', '22'],
#  ['힙합', '슬픔', '이별노래', '이별', '후', '듣다', '내', '노래', '같다', '이별', '노래'],
#  ['힙합',
#   '결산',
#   '연말결산',
#   '랩',
#   '2016_연말결산',
#   '국내힙합',
#   'HipHop',
#   'Rap',
#   '2016년올해의음악',
#   '2016년',
#   '2016년',
#   '되다',
#   '돌',
#   '아보',
#   '국내',
#   '힙합',
#   '총',
#   '결산'],
#  ['여름', '떠나자', '드라이브', '바다', '휴가', '떠나다', '싶다', '지금', '당장', '바다로'],
#  ['JPOP', '좋다', '오덕', 'power'],
#  ['휴식', '힐링', '여름', '주말', '편안함', '책임', '지는', '뉴에이지'],
#  ['카페음악',
#   '감성',
#   '어쿠스틱',
#   '차분한',
#   '힐링',
#   '어쿠스틱팝',
#   '팝',
#   '어쿠스틱',
#   '들려주다',
#   '깊다',
#   '감성',
#   '어쿠스틱',
#   '팝'],
#  ['기분전환', '여행', '크리스마스', '257'],
#  ['LG트윈스', '스트레스', 'lg', 'twins'],
#  ['밤', '새벽', '밤', '새벽', '생각', '나', '늘다', '노래'],
#  ['락', '넬', '크리스마스', '넬', '콘서트'],
#  ['비오는날',
#   '저녁',
#   '장마',
#   '카페',
#   '오후',
#   '드라이브',
#   '센치',
#   '감성',
#   '기분전환',
#   '흐리다',
#   '날',
#   '듣다',
#   '센치',
#   '감성',
#   '커피한잔'],
#  ['발라드', '아이유', '단독', 'concert', '2013'],
#  ['락', 'v', '-', 'hall', ':', '에브리싱글데이', '단독콘서트', 'just', 'one', 'day'],
#  ['OST', '계속', '듣다', '되다', '드라마', 'ost'],
#  ['축제',
#   'random',
#   'EDM',
#   'Mix',
#   '대학',
#   '락',
#   '신나는',
#   '대학',
#   '축제',
#   '시즌',
#   '!',
#   '같이',
#   '들다',
#   '좋다',
#   '신나다',
#   '노래',
#   '모음'],
#  ['감성곡',
#   '감각적인',
#   '휴식',
#   '감성팝',
#   '섬세',
#   '귓가',
#   '울리다',
#   '섬세',
#   '하고',
#   '감각',
#   '적',
#   '인',
#   'pop'],
#  ['신나는음악',
#   '하루를즐겁게',
#   '신선한음악',
#   '기분전환',
#   '왠지잘될것같은',
#   '잘모르는음악',
#   '여기',
#   '!',
#   '신나다',
#   '댄스',
#   '뮤직',
#   '!',
#   '하루',
#   '즐겁다',
#   '!',
#   '첫',
#   '번째'],
#  ['매장음악', '까페', '나', '직접', '말', '심플', '소울'],
#  ['한강',
#   '카페',
#   '잔잔한',
#   '귀르가즘',
#   '추억',
#   '휴식',
#   '감성',
#   '힐링',
#   '발라드',
#   '까페',
#   '내',
#   '맘',
#   '울컥',
#   '만들다',
#   '감성',
#   '띵곡'],
#  ['게임', '페이커', '롤', '노래', '들다', '면서', 'lol', '펜타킬', '싸다', '가능', '!'],
#  ['잠못드는밤', '잠들기전에듣는노래', '내', '기전', '들다', '려고', '만들다', '플레이', '리스트'],
#  ['1990',
#   '밴드',
#   '홍대',
#   '2000',
#   '모던록',
#   '가요',
#   '갈매기공화국',
#   '펑크',
#   '인디',
#   '뮤지션',
#   '로컬',
#   '이다',
#   '신의',
#   '축',
#   '갈매기',
#   '공화국',
#   '출신',
#   '뮤지션',
#   '들다'],
#  ['토토가',
#   '90년대가요',
#   '8090',
#   '90년대노래',
#   '8090세대',
#   '추억노래',
#   '8090댄스',
#   '90',
#   '년대',
#   '부터',
#   '최신',
#   '까지',
#   '기분전환',
#   '댄스'],
#  ['발라드', '★★★', '감미', '로', '운남', '자발라', '드', '★★★'],
#  ['댄스', '운동', '때'],
#  ['재즈', '재즈', '로', '채우다', '나', '하루'],
#  ['YB',
#   '국내록',
#   '추억',
#   '명곡',
#   '락',
#   '윤도현',
#   '가장',
#   '국적',
#   '인',
#   '록',
#   '사랑',
#   '받다',
#   '가수',
#   '윤도현'],
#  ['흥얼', '팝송', '흥얼', '거리', '며', '듣다', '팝송', '!'],
#  ['힐링', '휴식', '추억', '회상', '추억', '...', '소중하다', '사람', '남기다', '마지막', '선물'],
#  ['여행', '사랑', '설렘', '산책', '기분전환', '되다', '신나다', 'pop', '송', '모음곡'],
#  ['신유',
#   '조항조',
#   '트로트모음',
#   '트로트',
#   '노래방에서',
#   '주현미',
#   '안동역',
#   '트롯트',
#   '기분전환',
#   '노래방',
#   '트로트',
#   '후회',
#   '없다',
#   '완벽',
#   '선택',
#   '!!!',
#   '극도',
#   '로',
#   '사랑',
#   '보석',
#   '같다',
#   '트로트',
#   '선별'],
#  ['감성',
#   '드라이브',
#   '국내힙합',
#   '여행',
#   '휴식',
#   '기분전환',
#   '사랑',
#   '국힙',
#   '그냥',
#   '평범',
#   '국내',
#   '힙합',
#   '매주',
#   '업뎃'],
#  ['겨울',
#   '저녁',
#   '겨울감성',
#   '카페',
#   '취향저격',
#   '분위기',
#   'pub',
#   '팝',
#   '따뜻한',
#   '편안한',
#   '늦다',
#   '저녁',
#   '카페',
#   '펍',
#   '리스트',
#   'v',
#   '3',
#   '팝',
#   '록',
#   '알앤비',
#   '...'],
#  ['매장음악', '운동', '헤라', '디', '야', '흥겹다', '구나', '음악'],
#  ['팝송', '팝송모음', '너무', '좋다', '완전', '유명', '하진', '않다', '팝송', '(`', '･θ･´'],
#  ['혼자만의',
#   '걸을때',
#   '생각',
#   '밤',
#   '혼자',
#   '혼자',
#   '그냥',
#   '걷다',
#   '가사',
#   '귀',
#   '박히다',
#   '발걸음',
#   '멈추다',
#   '한참',
#   '머무르다'],
#  ['재즈', '감미', '로운', '선율', '흐르다', 'jazz'],
#  ['설렘', '사랑', 'ㅇㅇㅇㅇㅇ'],
#  ['겨울',
#   '감성',
#   '발라드',
#   '눈',
#   '잔잔',
#   '아티스트',
#   '사랑',
#   '이별',
#   'ballad',
#   '발라드',
#   '듣기',
#   '좋다',
#   '날',
#   '90-17년',
#   '까지',
#   '다',
#   '양하',
#   '게'],
#  ['가을', '까페', '가을', '바람', '불어', '오다', '저녁', '어쿠스틱', '팝'],
#  ['발라드', '봄', '함께', 'pop', '가요', '작다', '공간'],
#  ['비오는날', '밤', '새벽', '비', '오', '면', '난', '거', '들다', '어'],
#  ['경만', '저장용', '경만', '저장', '용'],
#  ['소울', '알앤비', '그냥', '즐기다', '음악'],
#  ['기분전환', '시티팝', '나들이', '드라이브', '봄', '듣다', '싶다', '살랑', '살랑', '시티', '팝', '느낌'],
#  ['힙합',
#   '오토튠',
#   '들썩들썩',
#   '명곡',
#   '그루브',
#   '내적댄스',
#   '신나는',
#   '내적',
#   '댄스',
#   'up',
#   '!',
#   '오토튠',
#   '사용',
#   '되다',
#   '해외',
#   '힙합'],
#  ['EMOTION', 'LOVE', 'the', 'french', 'dispatch'],
#  ['재즈', '재즈', '들다', '4월', '보내다'],
#  ['불금', '클럽', '주말', '핫', '클럽', '뮤직', '!!'],
#  ['힙합', '랩', '쇼', '밉다', '더머디', '화제', '되다', '역대', '인기', '곡'],
#  ['휴식',
#   '밤',
#   '연주곡',
#   '잔잔한',
#   '클래식',
#   '감성',
#   '마음',
#   '힐링',
#   '자장가',
#   '편안한',
#   '마음',
#   '힐링',
#   '편안',
#   '클래식',
#   '연주',
#   '곡'],
#  ['힙합', '랩', '토요일', '밤', '기분', '좋다', '레시피'],
#  ['코인노래방',
#   '나는가수',
#   '히트송',
#   '마이크',
#   '노래방',
#   '신나는',
#   '노래방',
#   '에서',
#   '신나다',
#   '부르다',
#   '노래'],
#  ['힙합', '랩', '힙합', '간지', '남', '@@@'],
#  ['여행', '기분전환', '산책', '아침', '듣다', '노래'],
#  ['SoulMin', '개인취향', '민우', 'MINU', 'minu'],
#  ['기분전환', '설렘', '사랑', '개강', '설레다', '사람', '필요', '노래'],
#  ['샤카칸',
#   '프린스',
#   '플레이리스트',
#   '너',
#   '제',
#   '틱',
#   '섹시',
#   'funk',
#   '빠져들다',
#   '수',
#   '밖에',
#   '없다',
#   '매력'],
#  ['휴식',
#   '가을',
#   '감성',
#   '드라이브',
#   '여행',
#   '힐링',
#   '기분전환',
#   '사랑',
#   '인디',
#   '신나는',
#   '학교',
#   '가다',
#   '길',
#   '기분',
#   '좋다',
#   '아지',
#   '살랑',
#   '살랑',
#   '힙',
#   '이다',
#   '노래',
#   '들다'],
#  ['피크닉',
#   '봄',
#   '달달',
#   '연애',
#   '나들이',
#   '썸',
#   '인디',
#   '봄',
#   '→',
#   '봄',
#   '↗',
#   '봄',
#   '↑',
#   '봄',
#   '!',
#   '오다',
#   '때',
#   '듣기',
#   '좋다',
#   '이다',
#   '음악',
#   '플레이',
#   '리스트'],
#  ['댄스', '신나다', '노래'],
#  ['classic',
#   '명반명연주',
#   '졸음운전예방',
#   '드라이브',
#   '에너지충전',
#   '의욕적인',
#   '기분전환',
#   '카타르시스',
#   '청소설거지',
#   '스트레스해소',
#   '열',
#   '정적',
#   '인',
#   '웅장',
#   '감동',
#   '클래식',
#   '오케스트라',
#   '첼로',
#   '바이올린'],
#  ['팝', '8090', '세대', '들다', 'oldpop', 'top', '40'],
#  ['비오는날',
#   '감성',
#   '봄',
#   'rain',
#   '비오는_날',
#   '사랑',
#   '비',
#   '오다',
#   '당신',
#   '함께',
#   '듣다',
#   '싶다',
#   '노래'],
#  ['차트',
#   '연말결산',
#   '취향저격',
#   '추억',
#   '프로필뮤직',
#   '카카오톡',
#   '2018',
#   '가요',
#   '인기',
#   '2018년',
#   '프로필',
#   '음악',
#   '많이',
#   '설정',
#   '되다',
#   '곡',
#   'top',
#   '30'],
#  ['휴식',
#   '주말',
#   '여유',
#   '여유',
#   '로운',
#   '주말',
#   '늦다',
#   '아침',
#   '부터',
#   '저녁',
#   '까지',
#   '홈',
#   '카페',
#   '즐',
#   '기기'],
#  ['힙합', '랩', '중독', '자꾸', '생각', '나', '늘다', '중독', '성', '랩', '힙합', '명곡', '모음'],
#  ['여름', '기분전환', 'hot', 'summer', '무덥다', '여름', '시원', '날다', '버리다', '노래'],
#  ['여름', '설렘', '사랑', '늦', '여름', '러브', '♥', '송'],
#  ['뉴에이지', '상쾌', '함', '안기다', '뉴에이지', '피아노'],
#  ['힐링', '휴식', '감성', '충만'],
#  ['록메탈', 'Metal', 'OST', '메탈', 'Rock', '록', 'f', '*', 'ck', 'up', '!!!.'],
#  ['카페음악',
#   '로맨틱',
#   '기분좋은',
#   '취향저격',
#   '연인',
#   '매장',
#   '설렘',
#   '데이트',
#   '사랑',
#   '달달',
#   '달달',
#   '멜로디',
#   '설레다',
#   '가득'],
#  ['여름', '팝송', '일상', '기분전환', '스트레스', '신나는', '여름', '분위기', '더욱', '화끈', '!'],
#  ['여름', '짜증', '스트레스', '클래식', '여름', '듣다'],
#  ['감성', '0802', '0802'],
#  ['휴식',
#   '그루비',
#   '멜로우',
#   '사색',
#   '부드러운',
#   '비트감있는',
#   '칠_Chill',
#   '로파이',
#   '멜로',
#   '우',
#   '비트'],
#  ['비오는날', '슬픔', '이별', '괜스레', '가슴', '답답', '하고', '우울', '때', '...'],
#  ['기분전환', '드라이브', '자신감', '샘솟다', '힘나다', '노래', '들다', '❤'],
#  ['힐링', '휴식', '기분전환', '우리', '소리', '찾다', '국악', '마당'],
#  ['7080',
#   '트로트',
#   '분위기',
#   '성인가요',
#   '부장님',
#   '애창곡',
#   '노래방',
#   '회식',
#   '신입사원',
#   '신나는',
#   '신입사원',
#   '회식',
#   '분위기',
#   'up',
#   '시키다',
#   '노래방',
#   '트로트'],
#  ['하루',
#   '감성',
#   '봄',
#   '퇴근길',
#   '잔잔한',
#   '하루',
#   '끝내',
#   '고',
#   '집',
#   '가다',
#   '길',
#   '들다',
#   '좋다',
#   '노래',
#   '하교',
#   '퇴근'],
#  ['팝', '추억', '팝송'],
#  ['락', '라디오', '729'],
#  ['락', '카페', '에서', '듣기', '좋다', '음악'],
#  ['팝', 'michael', 'jackson'],
#  ['팝', '사운드', '좋다', '해외', '인', '디'],
#  ['봄', '봄', '어울리다', '신나다', '거나', '부드럽다', '거나'],
#  ['집중',
#   '겨울',
#   '휴식',
#   '매장음악',
#   '카페',
#   '잔잔한',
#   '취향저격',
#   '감성',
#   '기분전환',
#   '스트레스',
#   '카페',
#   '가득',
#   '채우다',
#   '감성',
#   '노래'],
#  ['밤', '까페', '새벽', '가볍다', '듣기', '좋다', 'pop'],
#  ['휴식', '힐링', '기분전환', '묻히다', '까운', '...', '재', '조명', '해', '보고', '싶다', '곡'],
#  ['힐링', '휴식', '밤', '새벽', '잠', '오지', '않다', '때', '노래', '들다'],
#  ['연애세포를_깨우는_노래',
#   '썸',
#   '연애',
#   '외로운날',
#   '써니사이드',
#   '썸',
#   '못',
#   '타지',
#   '노래',
#   '로',
#   '썸',
#   '타다',
#   '방법'],
#  ['월드뮤직', '카페', '다니엘', '_', '퓨전', '국악'],
#  ['잔잔한',
#   '겨울밤',
#   '추억',
#   '꿀성대',
#   '슬픔',
#   '슬플때',
#   '이별',
#   '발라드',
#   '갑자기',
#   '문득',
#   '네',
#   '떠오르다',
#   '듣다',
#   '되다',
#   '발라드'],
#  ['추억', '회상', '풋풋', '가수', '들다', '초창', '기', '앨범'],
#  ['여름', '드라이브', '청량', '썸머', '시원한', '청량감', '시즌', '송', '-', '여름'],
#  ['설렘', '사랑', '밉다', '치치', '않다', '고서', '어떻다', '사랑', '하니'],
#  ['팝', '가을', '시작', '되다', '9월', '노래', '팝', '넘버', '들다'],
#  ['힐링', '휴식', '잔잔한', '이대', '로', '묻히다', '까운', '아이돌', '숨다', '명곡', '들다'],
#  ['힙합', '랩', '편하다', '듣기', '좋다', '힙합', '조세호', '오', '~~~'],
#  ['여름', '드라이브', '여름날', '차안', '에서', '듣기', '좋다', '노래'],
#  ['발라드', '＃＃', '90', '년대', '발라드'],
#  ['김윤아',
#   '자우림20',
#   '콘서트',
#   '20주년',
#   '이선규',
#   'JAURIM',
#   '김진만',
#   '셋리스트',
#   '이화여대삼성홀',
#   '자우림',
#   '170818-0820',
#   '자우림',
#   '20'],
#  ['힐링', '휴식', '설렘', '사랑', '잔잔', '기타', '반주', '따다', '봄날', '어쿠스틱', '노래'],
#  ['힐링', '저녁', '팝', '휴식', '노을', '노을', '지는', '해질녘', '분위기'],
#  ['아비치',
#   'DJ',
#   '프로듀서',
#   '일렉트로팝',
#   'EDM',
#   'Producer_DJ',
#   'electronica',
#   '2000',
#   '송라이터',
#   '레전드',
#   'edm',
#   '신',
#   '천재',
#   '프로듀서',
#   'dj',
#   '아비치'],
#  ['HIP',
#   '분위기',
#   '밤',
#   '해외',
#   '새벽',
#   '잠들다',
#   '전',
#   '듣기',
#   '좋다',
#   '감',
#   '성적',
#   '인',
#   '해외',
#   'r&b',
#   'hip',
#   '-',
#   'hop',
#   '#',
#   '2'],
#  ['요즘듣는노래', '요즘', '듣다', '노래'],
#  ['휴식',
#   '드라이브',
#   '여행',
#   '감성',
#   '이달잘듣',
#   '신나는',
#   '이번',
#   '달',
#   '자다',
#   '들다',
#   '!',
#   '2019',
#   'september'],
#  ['락', '들다', '수록', '흠뻑', '빠져들다', '노래', '모음'],
#  ['LP바',
#   '록명곡',
#   '간지',
#   '혼자듣는_록',
#   'lp',
#   '바',
#   '에서',
#   '들다',
#   '간지',
#   '나',
#   '늘다',
#   '음악',
#   '클래식',
#   '록',
#   '&',
#   '팝'],
#  ['여행', '운동', '산책', '떠나다', '싶다', '!', '달리', '고', '싶다', '!'],
#  ['하우스',
#   '트로피컬하우스',
#   '아이돌',
#   '딥하우스',
#   'idol',
#   '딥',
#   '하우스',
#   '-',
#   '트로피',
#   '컬',
#   '하우스',
#   '장르',
#   '아이돌',
#   '노래',
#   '!'],
#  ['여름',
#   '명절',
#   '운동',
#   '댄스',
#   '드라이브',
#   '개신나는노래',
#   '여행',
#   '기분전환',
#   '스트레스',
#   '휴가',
#   '드라이브',
#   '개다',
#   'feat',
#   '스트레쓰'],
#  ['기분전환', '설렘', '사랑', '3월', '활', '기차', '게', 'deep', 'chillout', 'mix'],
#  ['비오는날',
#   '감성',
#   '밤',
#   '여유',
#   '알앤비',
#   '새벽',
#   '재즈',
#   '위로',
#   '분위기',
#   '소울',
#   '새벽',
#   '혼자',
#   '듣다',
#   '싶다',
#   '.....'],
#  ['연주곡',
#   '잔잔한',
#   '바이올린',
#   '방콕',
#   '엘가',
#   '피아노',
#   '네오클래식',
#   '사랑의인사',
#   '클래식',
#   '내',
#   '손',
#   '안',
#   '에서',
#   '즐기다',
#   '클래식',
#   '-',
#   '4월',
#   '4',
#   '주차'],
#  ['감성적인', '명곡', '따뜻한', '추위를_녹이는', '마음', '따뜻하다', '어루', '지는', '클래식', '음악'],
#  ['슬픔', '감성', '이별', '밤에', '발라드', '감', '성터', '지는', '밤', '✨'],
#  ['뉴에이지', '비다', '날', '뉴에이지', '플레이', '리스트'],
#  ['추억', '기분전환', '회상', '보아', '음악'],
#  ['겨울', '까페', '우리', '겨울'],
#  ['여름', '까페', '그늘', '아래', '서', '듣다', '음악'],
#  ['FORK',
#   'kpop',
#   'indie',
#   'Rock',
#   'Metal',
#   'Pop',
#   'dance',
#   'Live',
#   'Remake',
#   'IDOL',
#   'never',
#   'ending',
#   'story',
#   'of',
#   'the',
#   'pop'],
#  ['겨울', '감성', '바람', '찰', '때', '불어', '오다', '감성'],
#  ['흥',
#   '드라이브',
#   'Pop',
#   '노래',
#   '폭발',
#   '광고음악',
#   '드라이브',
#   '자다',
#   '어울리다',
#   '노래',
#   '들다',
#   '!'],
#  ['혼자일때', '불면증', '밤', '봄날', '새벽', '잠', '못', '들다', '밤', '-', '♪'],
#  ['드라마ost', '영화OST', '드라마', '영화', 'ost', '들다', '마음', '편안', '히'],
#  ['저녁',
#   '매장음악',
#   '밤',
#   '카페',
#   '감각적인',
#   '분위기',
#   '센치',
#   '감성',
#   '기분전환',
#   '트렌디',
#   '센치',
#   '밤',
#   '듣다',
#   '감각',
#   '적',
#   '인',
#   '노래'],
#  ['퀸', '락', 'best', 'songs', 'of', 'queen'],
#  ['퇴근',
#   '운동',
#   '월요병',
#   '걸을때',
#   '음색',
#   '모닝콜',
#   '출근',
#   '기분전환',
#   '산책',
#   '고막여친',
#   '출퇴근길',
#   '상큼',
#   '고막',
#   '여친',
#   '노래'],
#  ['겨울',
#   'Obey',
#   'RnBR',
#   'HipHop',
#   '힐링',
#   '기분전환',
#   '스키장',
#   '코코아',
#   '한겨울',
#   '스키장',
#   '에서',
#   '마시다',
#   '따뜻하다',
#   '코코아',
#   '한잔',
#   '같다',
#   '음악',
#   '들다'],
#  ['크리스마스', '느낌', '크리스마스', '느낌', '제대로', '느끼다', '보기', '!'],
#  ['쓸쓸하고_찬란하',
#   '김고은',
#   '유인나',
#   '도깨비',
#   'OST',
#   '공유',
#   'TVN',
#   '육성재',
#   '이동욱',
#   '쓸쓸',
#   '하고',
#   '찬란',
#   '하',
#   '神',
#   '도깨비',
#   'ost'],
#  ['아련한기억', 'Gfriend', '아침', '아련하다', '여자친구', '노래'],
#  ['OST', '드라마', 'o', 't', '모음'],
#  ['새벽감성',
#   '발라드',
#   '새벽',
#   '감성',
#   '100%',
#   '충전',
#   '..',
#   '잠',
#   '못',
#   '이루',
#   '밤',
#   '듣다',
#   '발라드'],
#  ['이불속에서듣는노래',
#   '자기전에듣기좋은노래',
#   '밤',
#   '새벽에듣기좋은노래',
#   '포근하고고요한노래',
#   '겨울',
#   '밤',
#   '포근하다',
#   '듣다',
#   '고요',
#   '하고',
#   '감미',
#   '로운',
#   '사랑',
#   '노래'],
#  ['힐링', '휴식', '겨울', '★', 'jazz', 'christmas', '♬', 'vol', '01', '★'],
#  ['잔잔한', '새벽', 'down'],
# ...
#   '안',
#   '지다'],
#  ['휴식', '힐링', '겨울', '입', '김속', '에서', '피어', '나', '늘다', '겨울', 'jazz'],
#  ['락', '라디오', '454'],
#  ['추억', '사랑', '설렘', '회상', '취향', '관통', '멜로디', '좋다', '노래'],
#  ['트렌디', '트렌디', '래퍼', 'kid', 'milli'],
#  ['추억', '스트레스', '회상', '리메이크', '되어다', '옛날', '가요', '들다'],
#  ['드라이브', '가사', '웃다', '!', '리듬', '웃다', '!', '코믹', '송', '!!!'],
#  ['자기_전에', '새벽_분위기', '잔잔한_노래', '자기', '전', '듣기', '좋다', '곡'],
#  ['역주행_했으면_하는노래', '역주행', '카페', '가을', '노래', '뜨다', '같다', '역주행', '같다', '노래'],
#  ['OST', '2010', '명품', 'ost'],
#  ['휴식',
#   '매장음악',
#   '카페',
#   '알앤비',
#   '운동',
#   '드라이브',
#   '여행',
#   '기분전환',
#   '소울',
#   '자꾸만',
#   '듣다',
#   '싶다',
#   '지는',
#   'fresh',
#   '음악',
#   '!'],
#  ['카페', '커피', '봄', '로맨틱', '두근두근', '봄날', '로맨스', '♬'],
#  ['가을',
#   '오후',
#   '드라이브',
#   '바람',
#   '산책',
#   '팝',
#   '일렉',
#   '드라이브',
#   '하',
#   '면서',
#   '듣다',
#   '일',
#   '렉팝'],
#  ['휴식',
#   '비',
#   '가을',
#   '잔잔한',
#   '새벽',
#   '피곤',
#   '집',
#   '위로',
#   '힐링',
#   '어떻다',
#   '일로',
#   '든',
#   '힘들다',
#   '하고',
#   '당신',
#   '위로',
#   '되어다',
#   '드릴',
#   '게',
#   '요'],
#  ['설렘', 'cantarococo', '3'],
#  ['여행', '드라이브', '산책', '탄산음료', '말다', '듯', '청량하다', '느낌', '노래'],
#  ['겨울', '잔잔한', '발라드', '슬픔', '설렘', '사랑', '이별', '센치', '발라드', '모음'],
#  ['드라이브', '락', 'dj딘', '드라이브', '해외', '락', 'no', '3'],
#  ['반복재생하게만드는곡',
#   '가사가좋은노래',
#   '무한재생',
#   '중독성',
#   '기분전환',
#   '사랑',
#   '검정치마',
#   '달달',
#   '인디',
#   '곡',
#   '무한',
#   '반복',
#   '&',
#   '이다',
#   'feat',
#   '검정치마'],
#  ['추억', '기분전환', '회상', '꼭', '들다', '보다', '아이돌', '수록', '곡', 'list'],
#  ['비오는날', '잔잔한', '비다', '날', '딱이다', '노래'],
#  ['뉴에이지', '맑다', '푸른', '가을', '하늘', '담다', '상쾌', '뉴에이지'],
#  ['까페', '잔잔한', '사무실', '에서', '업무', '중', '듣기', '편안', '클래식', '베스트'],
#  ['kpop',
#   '통근',
#   '케이팝',
#   '아이돌',
#   '출근',
#   '퇴근',
#   '댄스',
#   '가요',
#   '2010',
#   '신나는',
#   '작곡가',
#   '안드레아스',
#   '오베르',
#   '케이팝',
#   '작품',
#   '들다'],
#  ['소울', '알앤비', '16', '번째', 'dj', '플레이', '리스트'],
#  ['락', 'sitara'],
#  ['추억', '회상', '웃다', '때'],
#  ['우울', '감성', '우울', '감성', '터', '지는', '곡', '모음'],
#  ['기분전환',
#   '휴식',
#   '감성',
#   '드라이브',
#   '여행',
#   '뮤지션',
#   '들이다',
#   '좋다',
#   '아하',
#   '뮤지션',
#   '노래',
#   '어떻다'],
#  ['비오는날', '흐린날', '감성', '라디오', '발라드', '라디오', '꼭', '나오다', '노래'],
#  ['담배', '감성', '비', '센치', '섹후땡', '비', '오다', '센치', '날', '섹', '후', '땡'],
#  ['새벽', '이별', '감성', '발라드', '이별', '후', '들다', '공감', '늘다', '노래'],
#  ['클래식', '클래식', '최신', '곡', '모음', '집', '2015년', '04월', '30일'],
#  ['인디', '새벽', '잠들다', '전', '듣기', '좋다', '노래'],
#  ['일렉트로니카',
#   'RNBSOUL',
#   'EDM',
#   '드라이브',
#   '때',
#   '듣기',
#   '좋다',
#   'disclosure',
#   '추천',
#   '곡',
#   '모음'],
#  ['소울', '알앤비', 'secret', 'garden', 'part', '3'],
#  ['힙합', '랩', '가사', '전달', '힙합'],
#  ['1990',
#   'ToniBraxton',
#   '베이비페이스',
#   '팝알앤비',
#   'since2000',
#   '음악파트너',
#   'Pop',
#   '토니블랙스톤',
#   'Babyface',
#   '90',
#   '년대',
#   '팝',
#   '시장',
#   '공략',
#   'r&b',
#   '콤비',
#   '베이비페이스',
#   '토니',
#   '브랙스',
#   '톤'],
#  ['알앤비', '취향', '저격', '!', '알앤비', '소울'],
#  ['인디', '이다', '뮤지션', '들이다', '전하', '고양이', '이야기'],
#  ['슬픔', '그리움', '미련', '눈물', '이별후', '이별', '후', '헤', '어진', '다', '늘다', '건'],
#  ['바보', '테스트', '2'],
#  ['밤', '새벽', 'sdy', '6279', '새벽', '듣기', '좋다', '2'],
#  ['산책', '드라이브', '여행', '드라이빙', 'emotion', '-', '신나다', '팝송', '♬'],
#  ['비오는날', '밤', '새벽', '조용조', '용하다'],
#  ['팝', '캘리', '주말', '용'],
#  ['새벽', '추억', '밤', '회상', '플레이', '리스트', '중', '가장', '아끼다', '곡'],
#  ['힙합', '랩', '한국힙합', '기분전환', '힙합노래', '한국', '힙합', '노래', '듣다', '싶다', '때', '!'],
#  ['힐링', '뉴에이지', '30', '초면', '마음', '편안', '해지', '피아노', '멜로디'],
#  ['보고싶은', '밤', '우울한', '노래', '대신', '울다', '밤'],
#  ['클래식', '자장가', '들다', '1초', '만에', '잠들다', '자장가', '모음', '❣'],
#  ['여름',
#   'LANY',
#   '세젤힙',
#   'Pop',
#   '레이니',
#   '힙한',
#   '팝추천',
#   '휴가',
#   '여름',
#   '휴가',
#   '!',
#   '공항',
#   '늘다',
#   '길',
#   '듣다',
#   'pop'],
#  ['힙합', '랩', '2010', '년대', '국내', '해외', '재즈', '힙합', 'jazz', 'hiphop'],
#  ['클래식', '여유', '클래식', '음악', '들다'],
#  ['새벽', '밤', '잔잔한', '감성', '자극', '하고', '싶다', '때'],
#  ['따뜻',
#   '달달',
#   '가을',
#   '포근한',
#   '11월',
#   '쌀쌀',
#   '날씨',
#   '함께',
#   '포',
#   '근',
#   '하고',
#   '달달',
#   '음악'],
#  ['소울', '알앤비', '해외', '네오소울', '모음', '-', '2'],
#  ['비오는날',
#   '흐린날',
#   '장마',
#   '새벽',
#   '버스',
#   '센치',
#   '집',
#   '침대',
#   '우울',
#   '쌀쌀한',
#   '흐리다',
#   '날',
#   '비',
#   '오는',
#   '날',
#   '어울리다',
#   '나르다',
#   '한음',
#   '악'],
#  ['재즈', '재즈', '몰다', '라도', '들다', '귀가', '즐겁다', '지는', '째즈'],
#  ['여름날', '뉴에이지', '여름날', '듣기', '편안', '뉴에이지'],
#  ['락', 'soulasylum'],
#  ['발라드', '소중하다', '7080'],
#  ['발라드', '러블', '리모', '드'],
#  ['아이유', '아이유노래', '아이유노래모음', '아이유', '노래'],
#  ['힙합',
#   '자랑',
#   '쿨한',
#   '개성',
#   '멋진',
#   '크루',
#   '힙한',
#   '트렌디',
#   '앰비션뮤직',
#   '언더',
#   '공중도덕',
#   '스웩',
#   '!',
#   '앰비션',
#   '뮤직',
#   '베스트'],
#  ['힙합',
#   '알앤비',
#   '새벽',
#   '드라이브',
#   '그루브',
#   '알앤비힙합',
#   '딘',
#   '저절로',
#   'groove',
#   '타다',
#   '되다',
#   '국내',
#   '힙합',
#   '들다',
#   '볼',
#   '래',
#   '?'],
#  ['까페', '설렘', '사랑', '원', '곡', '보다', '아름', '다운', '커버', '곡'],
#  ['왜태그하라는거야난태그싫은데', '여름', '여름', '바람결', '지는', '같다', '노래', '들다'],
#  ['여행', '기분전환', '산책', '★', '여행가', '길', '듣기', '좋다', 'music', '★'],
#  ['비오는날', '기분전환', '밖에', '비', '계속', '오다', '....', '비다', '들다', '어보', '세요'],
#  ['겨울', '설렘', '사랑', '미리', '메리크리스마스'],
#  ['힙합', '랩', '취향', '저격', '감성', '힙합', '+', 'α'],
#  ['집중',
#   '회상',
#   '쓸쓸하고',
#   '추억',
#   '그리움',
#   '슬픔',
#   '설렘',
#   '사랑',
#   '이별',
#   '스트레스',
#   '지난날',
#   '그리',
#   '울',
#   '때',
#   '...'],
#  ['힙합', '랩', '멜로디', '좋다', '이다', '힙합', '♪'],
#  ['기분전환', '젠', '잊다'],
#  ['슬픔', '추억', '이별', '회상', 'theme', ':', '전화'],
#  ['발라드', '느낌', '노래', '♪'],
#  ['감성',
#   '밤',
#   '새벽',
#   '랩',
#   '피쳐링',
#   '비트',
#   '보컬음색',
#   '감',
#   '성적',
#   '인',
#   '비트',
#   '보석',
#   '같다',
#   '피쳐링'],
#  ['겨울', '감성', '발라드', '뼛속', '까지', '시리다', '겨울', '따다', '발라드', '한잔', '?'],
#  ['설렘', '사랑', '내다', '내다', '아니다', '사람', '떠올리다', '듣다', '노래'],
#  ['리메이크', '회상', '노래방에서', '커버', '추억', '여행', '추억', '돋다', '리메이크', 'cover'],
#  ['피아노', '뉴에이지', '잔잔한', '7월', '빗줄기', '잔잔', '뉴에이지'],
#  ['밤', '까페', '새벽', '추천', '가을', '감성', '노래'],
#  ['발라드', '슬프다', '때', '들다', '더', '슬프다', '노래'],
#  ['기억조작',
#   '시원해지는',
#   '에너지충전',
#   '로큰롤',
#   '듣기',
#   '해도',
#   '시원',
#   '하이',
#   '틴',
#   'st',
#   '곡',
#   '모음'],
#  ['봄', '심장', '울', '리다', '.....'],
#  ['재즈', '재즈', '함께', '시원', '하루', '~!'],
#  ['잔잔한',
#   '감성',
#   '새벽',
#   '새벽',
#   '뭐',
#   '들다',
#   '?',
#   '새벽',
#   '듣기',
#   '좋다',
#   '잔잔',
#   '하고',
#   '감',
#   '성터',
#   '지는',
#   '곡'],
#  ['휴식',
#   '느낌있는',
#   '카페',
#   '감각적인',
#   '그루브',
#   '감성힙합',
#   '기분전환',
#   '혼술',
#   '리드미컬',
#   '바운스',
#   '한번',
#   '들다',
#   '계속',
#   '듣다',
#   '싶다',
#   '만들다',
#   '감성',
#   '힙합',
#   '띵곡들'],
#  ['Lullaby', '자장가', 'for', 'kj'],
#  ['비오는날',
#   '휴식',
#   '연주곡',
#   '피아노',
#   '잔잔함',
#   '뉴에이지',
#   '설렘',
#   '겨울연가',
#   '힐링',
#   '겨울',
#   '밤',
#   '혼자',
#   '듣다',
#   '감성',
#   '자극',
#   '연주',
#   '곡'],
#  ['사극OST',
#   '서정적',
#   '퓨전재즈',
#   '잔잔한',
#   '슬픈노래',
#   '퓨전국악',
#   '아련함',
#   '델리민주',
#   '달빛',
#   '▲',
#   '아련하다',
#   '달빛',
#   '여인',
#   '여배우',
#   'bgm',
#   '퓨전',
#   '국악',
#   '추천'],
#  ['윤종신', '좋니', '콘서트', '2018', '윤종신', '전국투어', '셋업', '리스트'],
#  ['겨울',
#   '카페',
#   '보사노바',
#   '난로',
#   '재즈',
#   '커피',
#   '추위',
#   '따뜻하다',
#   '난로',
#   '틀',
#   '고',
#   '보사노바',
#   '음악',
#   '틀',
#   '고'],
#  ['감성', '느낌있는', '밤', '카페', '새벽', '분위기', '알앤비', '사랑', '이별', 'r', '&', 'b'],
#  ['팝송을',
#   '아침',
#   '드라이브',
#   '기분전환',
#   '트렌디',
#   '주말에',
#   '신나는',
#   '기분전환',
#   '!',
#   '신나다',
#   '주말',
#   '원한',
#   '다',
#   '면'],
#  ['잔잔한노래',
#   '겨울',
#   '발라드',
#   '취향저격',
#   '추억',
#   '감성충전',
#   '사랑',
#   '이별',
#   '인디',
#   '가사',
#   '공감',
#   '하고',
#   '멜로디',
#   '빠져들다',
#   '노래'],
#  ['페미니즘', '여성', 'feminism'],
#  ['설레임', '그리움', '마음', '찌질하다', '때'],
#  ['기분전환', '매장음악', '정말', '흔', '치', '않다', '노래', '란', '이렇다', '아니다', 'xd'],
#  ['저녁', '밤', '새벽', '추억', '쓸쓸하게', '슬픔', '설렘', '이별', '회상', '감미로운', '밤', '...'],
#  ['Pop', '앨범아트', '부터', '취향', '저격'],
#  ['일렉', '★', '월요병', '이기다', '음악', '★'],
#  ['휴식',
#   '카페',
#   '알앤비',
#   '감성',
#   '기분전환',
#   '사랑',
#   '무드있는',
#   '카페',
#   '에서',
#   '듣다',
#   '해외',
#   'r&b',
#   '매달',
#   '업데이트'],
#  ['트랜디한노래', '내', '좋다', '아하', '뭘', '좋다', '트랜디', '힙', '노래', '~~*'],
#  ['가을감성', '리메이크', '가을', '마음껏', '느끼다', '수', '숨기다', '리메이크', '감성', '곡'],
#  ['이별하다', '이별', '이별노래', '이별곡', '이별', '후', '공감', '가다', '노래', '가사'],
#  ['밴드',
#   '운동',
#   '스트레스',
#   '락킹',
#   '국내',
#   '락',
#   '인디',
#   '추다',
#   '땐',
#   '락킹',
#   '점프',
#   '뛰다',
#   '면서',
#   '버티다',
#   '안',
#   '그래',
#   '?'],
#  ['바람', '일상', '가을', '듣기', '편안', '플레이', '리스트', ':)'],
#  ['저녁',
#   '밤',
#   '회상',
#   '추억',
#   '그리움',
#   '설렘',
#   '사랑',
#   '퇴근길',
#   '감미로운',
#   '새벽',
#   '퇴근길',
#   '귓가',
#   '들려오다',
#   '보이스'],
#  ['소름',
#   '감성',
#   '밤',
#   '잔잔한',
#   '발라드',
#   '노을',
#   '저녁',
#   '가요',
#   '노을',
#   '지는',
#   '저녁',
#   '..',
#   '#',
#   '감성',
#   '발라드'],
#  ['겨울',
#   '감성',
#   '매장음악',
#   '겨울감성',
#   '카페',
#   '겨울밤',
#   '드라이브',
#   '저녁',
#   '포근한',
#   '겨울',
#   '저녁',
#   '듣다',
#   '따뜻하다',
#   '손',
#   '난로',
#   '같다',
#   '보이스',
#   '라떼'],
#  ['봄',
#   '카페',
#   '봄바람',
#   '방콕',
#   '발라드',
#   '드라이브',
#   '벚꽃',
#   '힐링',
#   '사랑',
#   '외로움',
#   '자다',
#   '이루',
#   '밤',
#   '달달',
#   '꿀맛',
#   '같다',
#   '자장가',
#   '함께'],
#  ['밤', '새벽', '시절', '노래', '들다'],
#  ['힙합',
#   '감성',
#   '감성힙합',
#   '학창시절',
#   '싸이월드',
#   '한국힙합',
#   '중고',
#   '딩때',
#   '좋다',
#   '아하',
#   '던',
#   '힙합'],
#  ['락', '{', '추천', '}', '록', '&', '메탈', '모음'],
#  ['힙합',
#   '신나는음악',
#   'RnB',
#   '신나는힙합',
#   '드라이브',
#   '올드스쿨',
#   '30대',
#   '90',
#   '&',
#   '00',
#   '>>',
#   'r&b',
#   'hiphop',
#   'rap'],
#  ['트로트', '드라이빙', '음악', '-', '트롯', '트'],
#  ['밤', '까페', '새벽', '센치', '봄밤', '혼자', '혹은', '누군가', '♪'],
#  ['소울', '알앤비', 'r&b', 'soul', '모음'],
#  ['이별', '새벽', '밤', '슬픔', '감성', '자극', '이별', '노래', '들다'],
#  ['추억', '기분전환', '회상', '기억', '나니', '?', '2000', '밀레니엄', '유행', '팝송', '!'],
#  ['재즈', '클럽', '에반스', ':', '더', '버건디', '콘서트'],
#  ['라디오',
#   'FM4U',
#   'MBC',
#   '배캠',
#   '30주년',
#   '200319',
#   'mbc',
#   'fm',
#   '4',
#   'u',
#   '라디오',
#   '20.03',
#   '19',
#   '목',
#   ':',
#   '모여',
#   '라',
#   '배캠',
#   '30',
#   '주년'],
#  ['아침',
#   '주말',
#   '오후',
#   '작업할때',
#   '집',
#   '긍정적',
#   '산책',
#   '집순이',
#   '침대',
#   '혼자만의시간',
#   '오늘',
#   '집',
#   '순이',
#   '음악',
#   '틀어놓다',
#   '뒹굴뒹굴',
#   '놀다',
#   '1'],
#  ['ITZY', '있지', 'itzy', '?', '!', 'itzy', '노래', '모으다', '듣다', '!'],
#  ['잔잔한',
#   '겨울',
#   '휴식',
#   '밤',
#   '새벽',
#   '추억',
#   '설렘',
#   '사랑',
#   '밤',
#   '센치',
#   '노래',
#   '듣다',
#   '고자',
#   '요'],
#  ['댄스', '무한도전', '낳다', 'artist', '들다', '그리', '고', '음악', '☆'],
#  ['슬픔', '이별', '이별', '하고', '들다', '더', '슬프다', '곡'],
#  ['겨울', '설렘', '사랑', '오다', '겨울', '너', '같이', '듣다', '싶다', '노래'],
#  ['락', '잠비', '나이', '국악', '록', '?)'],
#  ['1950_60',
#   'country_blues',
#   '델타지역',
#   '팝',
#   '백인블루스록',
#   'PBB',
#   '미시시피',
#   '폴버터필드블루스밴드',
#   '블루스',
#   '락',
#   '백인',
#   '블루스',
#   '포크',
#   '결합',
#   '폴',
#   '버터',
#   '필드',
#   '블루스',
#   '밴드'],
#  ['하루',
#   '아침',
#   '상쾌한',
#   '기분전환',
#   '일상',
#   '신나는',
#   '하루',
#   '상쾌',
#   '!',
#   '기분',
#   '좋다',
#   '아지',
#   '곡',
#   '모음'],
#  ['잔잔한', '감성', '팝송', '새벽', '새벽', '창가', '앉다', '듣다', '노래'],
#  ['힙합', '국내알앤비', '감성', '알앤비', 'RnB', '반드시', '들다', '국내', 'r&b'],
#  ['밴드',
#   'guitarriff',
#   'GUITAR',
#   'riff',
#   '기타리프',
#   'Rock',
#   '참이슬',
#   'rock',
#   '에서',
#   '빠지다',
#   '수',
#   '없다',
#   'guitar',
#   'riff'],
#  ['추억',
#   '사랑',
#   '설렘',
#   '회상',
#   '2030',
#   '대다',
#   '그때',
#   '시절',
#   '..',
#   '우리',
#   '들다',
#   '노래',
#   '~!!'],
#  ['힐링', '휴식', '밤', '새벽', '새벽', '산책길', 'with', '잔잔', '노래', '들다'],
#  ['비오는날',
#   '감성',
#   '가을',
#   '잔잔한',
#   '드라이브',
#   '불금',
#   '기분전환',
#   '센치하게',
#   '비',
#   '오다',
#   '날',
#   '감성',
#   '충천',
#   '시키다',
#   '플레이',
#   '리스트',
#   ':)'],
#  ['락', 'dj', '곰', '_', '스노우보딩'],
#  ['겨울', '겨울노래', 'Winter', '크리스마스', '겨울', '노래'],
#  ['우울할때',
#   '감성',
#   '카페',
#   '잔잔한',
#   '발라드',
#   'Pop',
#   '잠잘때',
#   '조용한',
#   '잠안올때',
#   '불면증',
#   '잔잔',
#   '계속',
#   '업데이트'],
#  ['어쿠스틱',
#   '혼자',
#   '발라드',
#   '드라이브',
#   '가사',
#   '조용한',
#   '띵곡만',
#   '산책',
#   '퇴근길',
#   '인디',
#   '조',
#   '용한',
#   '분위기',
#   '어울리다',
#   '멜로디'],
#  ['슬픔', '추억', '이별', '회상', '그래', '네', '없다', '어도', '나', '괜찮다'],
#  ['휴식',
#   '클래식피아노',
#   '카페',
#   '명품클래식',
#   '커피',
#   '피아노클래식',
#   '클래식',
#   '일상',
#   '감미로운',
#   '감미',
#   '로운',
#   '클래식',
#   '피아노',
#   '일상',
#   '여유'],
#  ['추억', '가을', '회상', '가을', '느낌', '물씬', '나', '늘다', '음악'],
#  ['발라드', '우울', '하루'],
#  ['잔잔', '연주', '사랑', '하루', '마치', '며', '듣다', '음악', '들다'],
#  ['비오는날',
#   '잔잔한',
#   '장마',
#   '새벽',
#   '발라드',
#   '위로',
#   '기분전환',
#   '사랑',
#   '이별',
#   '밤',
#   '이별',
#   '후',
#   '오다',
#   '닿다',
#   '가사',
#   '좋다',
#   '노래',
#   '들다'],
#  ['브이앱',
#   '필레이리스트',
#   'DAY6',
#   '데이식스추천',
#   '추천곡',
#   'V앱',
#   '데이식스',
#   '원필',
#   '원',
#   '필',
#   '이의',
#   '필레',
#   '이리스',
#   '트',
#   '3',
#   '추천',
#   '곡',
#   '180708'],
#  ['락', '푸른밤', '플레이', '리스트', '04'],
#  ['서늘한', '같이', '듣기', '산책', '서늘하다', '날', '산책', '듣기', '좋다', '노래'],
#  ['까페', '커피', '클래식', '나', '휴식'],
#  ['락', '라디오', '70'],
#  ['잔잔한', '감성', '팝', '가을밤', '#나만알고싶은', '가을', '밤', '감', '성터', '지는', '팝', '#'],
#  ['부산',
#   '휴가',
#   'CASS',
#   'underbridge',
#   'fresh',
#   'party',
#   '라인업',
#   '!!',
#   '예습',
#   '하고',
#   '놀다',
#   '^^^'],
#  ['듀엣', '취향저격', '달달', '피쳐링', '사랑', '남녀', '사랑', '스러운', '남녀', '듀엣'],
#  ['인디', '오뙤르', '4', '주년', '기획', '공연', '3월', '13~17일'],
#  ['힙합',
#   '중독성',
#   '후렴',
#   '국힙',
#   '아무생각없이',
#   '훅',
#   '장인',
#   '들이다',
#   '빚',
#   '국힙',
#   '모음',
#   '중독',
#   '성',
#   '힙합',
#   '//',
#   '아무',
#   '생각',
#   '없이',
#   '듣기',
#   '좋다'],
#  ['운동', 'ArianaGrande', 'setlist', '꿀성대', '기분전환', '사랑', '아리아나', '내한'],
#  ['몽환적인',
#   '가사로듣는',
#   '락',
#   '밤',
#   '새벽',
#   '생각',
#   '많다',
#   '새벽',
#   '듣다',
#   '싶다',
#   '몽환',
#   '적',
#   '인',
#   '락',
#   '음악'],
#  ['특별한', '가을', '문득', '떠오르다', '그래', '..', '가을', '었', '지', '...', '381'],
#  ['오후', '잔잔한', '여유', '칠뮤직', '나른한', '나른하다', '오후', '뒹', '굴거리', '며', '듣다', '팝'],
#  ['OST', '불후', '명곡', '전설', '노래', '200회', '특집', '김수철', '1/2', '편', '원', '곡'],
#  ['설렘', '사랑', 'ra', 'd', 'best', 'songs'],
#  ['겨울',
#   '매장음악',
#   '해외',
#   '감각적인',
#   '경쾌한',
#   '그루브',
#   '기분전환',
#   '추위',
#   '한파',
#   '출퇴근',
#   '추위',
#   '에도',
#   '경쾌',
#   'step',
#   '!',
#   '감각',
#   '적',
#   '인',
#   'groove',
#   'pop'],
#  ['OST', '중국', '영화', '드라마', '에서', '만나다', '노래', '들다'],
#  ['가을', '설렘', '사랑', '설레다', '주의'],
#  ['집중',
#   '감성',
#   '가을',
#   '잔잔한',
#   '새벽',
#   '컨템포러리',
#   '작업할때',
#   '락발라드',
#   '밤샘',
#   '업무',
#   '새벽',
#   '까지',
#   '이다',
#   '지는',
#   '작업',
#   '지',
#   '칠',
#   '때',
#   '틀어놓다',
#   '자구',
#   '요',
#   '느낌'],
#  ['감성', '카페', '가을', '발라드', '새벽', '휴식', '사랑', '이별', '명곡', '발견'],
#  ['힙합',
#   '감성',
#   '잔잔한',
#   '랩',
#   '드라이브',
#   '여행',
#   '휴식',
#   '클럽',
#   '기분전환',
#   '신나는',
#   '좋다',
#   '랩',
#   '모으다',
#   '플레이',
#   '리스트'],
#  ['락', '아무', '렇', '지도', '않다', '맑은', '날'],
#  ['발라드', '내', '마음', '사랑'],
#  ['분위기',
#   'electronica',
#   '감각적인',
#   '실험적인',
#   '영국',
#   '퓨처개러지',
#   'EDM',
#   '신비한',
#   '트렌디',
#   '2010',
#   'uk',
#   '개다',
#   '21',
#   '세기',
#   '형',
#   '진화',
#   '퓨처',
#   '개다'],
#  ['새벽', '겨울연가', '밤', '사랑설렘', '겨울', '어울리다', '색깔', '노래', '모음'],
#  ['여름', '까페', '여름', '듣다', 'summer', 'love', 'coffee', '뮤직', 'no', '2'],
#  ['발라드', '희망', '노래', 'best', '모음', '집', '!'],
#  ['발라드', '새벽', '느낌'],
#  ['electro_house',
#   '컴플렉스트로',
#   'wooney',
#   '일렉트로하우스',
#   'ElectroHouse',
#   'complextro',
#   '일렉',
#   '장르',
#   '컴플렉스',
#   '트',
#   '로',
#   ':',
#   '일렉트로',
#   '하우스',
#   '덥스텝',
#   '런치',
#   '패드',
#   '조화'],
#  ['휴식',
#   '가을',
#   '연주곡',
#   '월요병',
#   '힐링',
#   '조용한',
#   '불면증',
#   '오후',
#   '가을',
#   '향기',
#   '점점',
#   '다가',
#   '올',
#   '때',
#   '듣다',
#   '연주',
#   '곡'],
#  ['감성', '카페', '까페', '듣기', '좋다', '노래'],
#  ['스트레스', '기분전환', '여자', '들다', '힙합'],
#  ['새벽', '밤', '잔잔한', '자다', '!'],
#  ['휴식', '힐링', '밤', '새벽', '예민', '감성', '자극', '시키다', '피아노', '곡'],
#  ['드라이브', '드라이브', '딱', '!', '좋다', '배경음악', '들다', '..'],
#  ['드럼', '피아노', '팝송', '기타', '악기', '드럼', '기타', '피아노', '중', '제일', '?'],
#  ['감성',
#   '밤',
#   '가을',
#   '운동',
#   '편안함',
#   '산책',
#   '팝',
#   '시원',
#   '밤',
#   '공기',
#   '함께',
#   '듣기',
#   '좋다',
#   '노래',
#   'ft',
#   '감성'],
#  ['슬픔', '이별', '센치', '우울', '잔잔', '하고', '슬프다'],
#  ['기분좋은',
#   '히트곡',
#   '봄',
#   '드라이브',
#   '벚꽃',
#   '연애',
#   '설렘',
#   '사랑',
#   '밤',
#   '시절',
#   '새내기',
#   '봄',
#   '06',
#   '학번',
#   '19',
#   '학번'],
#  ['가을바람', '힐링', '감성', '가을', '가을밤', '가을', '만날', '끄다', '?'],
#  ['겨울',
#   '카페',
#   '발라드',
#   '월요일',
#   '연애',
#   '사랑',
#   '썸',
#   '이별',
#   '추운날',
#   '인디',
#   '이별',
#   '점점',
#   '실감',
#   '나',
#   '늘다',
#   '오늘',
#   '듣다',
#   '발라드'],
#  ['테크노',
#   '전자음악',
#   '댄스',
#   '레전드',
#   '신스팝',
#   '일렉트로니카',
#   '옐로우매직오케스트라',
#   'YMO',
#   '제이팝',
#   '일렉',
#   '일본',
#   '일렉트로니카',
#   '신의',
#   '선구자',
#   'ymo'],
#  ['발라드', '나르다', '설', '레게', '노래', '#', '2'],
#  ['밤', '밤', '듣기', '좋다', '음악', '들다'],
#  ['뉴에이지', '사랑', '꿈꾸다', '모든', '음악'],
#  ['인스트루멘탈',
#   '저녁',
#   '재즈힙합',
#   '퇴근길',
#   '위로',
#   '되어다',
#   'instrumental',
#   'jazz',
#   'hiphop'],
#  ['힙합', '랩', '감성', '힙합', '종결'],
#  ['힐링', '휴식', '밤', '새벽', '잠자다', '때', '힘드다', '날', '힘', '내시', '라고', '...'],
#  ['해쉬태그', '134340'],
#  ['부모님',
#   '눈물',
#   '엄마',
#   '사랑해',
#   '아빠',
#   '어버이날',
#   '가족',
#   '고마워',
#   '가정의달',
#   '감사',
#   '언제',
#   '나',
#   '내',
#   '편',
#   '!',
#   '가족',
#   '소중하다',
#   '느끼다',
#   '노래'],
#  ['팝',
#   '감각적인',
#   '몽환적',
#   '매장음악',
#   '세련된',
#   '몽환',
#   '적',
#   '몽환',
#   '적',
#   '이며',
#   '몽환',
#   '적',
#   '인',
#   '리스트'],
#  ['여름', '휴식', '폴문', '드라이브', '힐링', '기분전환', '인디', '기분', '좋다', '하루', '만들다', '노래'],
#  ['행복하자', '케이팝', '새해맞이', '2019년', '올해', 'k', '-', 'pop', '띵곡들'],
#  ['비오는날', '밤', '듣다', '잔잔', '음악', '♪'],
#  ['힐링', '휴식', '추억', '회상', '추억', '속', '내', '미니홈피', 'bgm', '2004', '-', '2013'],
#  ['잔잔한', '밤', '새벽', '잔잔', 'pop'],
#  ['종현', '목소리', '샤이니', '종현', '기억', '해', '야', '목소리'],
#  ['트와이스', '일본타이틀', '트와이스', '일본', '타이틀곡', '모음'],
#  ['덥', '일렉', 'dubs'],
#  ['스트레스', '기분전환', '출퇴근길', '...', '귀', '정화', '하고가', '요', 'ㅋ'],
#  ['떡상',
#   '신예',
#   '새해',
#   '2020년',
#   '복많이받으세요',
#   '루키',
#   '루키',
#   '2020년',
#   '행보',
#   '기대',
#   '되다',
#   '신예',
#   '아티스트',
#   '!'],
#  ...]

# %%
from gensim.models.word2vec import Word2Vec
from gensim.models.callbacks import CallbackAny2Vec
import logging

# %%
model_song = Word2Vec(
                 # epochs = 5, # neural network 학습할 때 전체 training data를 몇번 돌리는지
                 vector_size = 100, # 임베딩을 하는 벡터의 사이즈 (hidden layer의 size)
                 min_count = 1, # 단어가 최소 등장해야될 횟수
                 # 단어가 겹치는게 많아야 학습이 잘됨, 너무 적으면 의미가 없음, data_preprocessing
                 workers = 4,
                 sg = 1, # skipgram을 사용한다면 1, 0을하면 CBOW가 됨
                 hs = 0, # negative sampling을 사용한다면 0 (hierarchical softmax)
                 negative = 50, # 1개의 positive sample당 negative sample의 개수
                 window = 30 # window를 크게 잡는 이유는 문장 내 모든 아이템끼리 학습이 되어야 하기 때문임
                 # 여기서 word2vec의 input은 집합이 아니라 list임, 그래서 window size를 크게 해야 모든 조합들이 
                 # 다 학습 데이터에 들어감
                 # item2vec의 집합으로 만들기 위해서 window size를 크게 함
                )

print(model_song)
# word_vectors = model.wv
# Out:
# Word2Vec(vocab=0, vector_size=100, alpha=0.025)

# %%
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.INFO)

class Callback(CallbackAny2Vec):
    def __init__(self):
        self.epoch = 1
        self.training_loss = []

    def on_epoch_end(self, model):
        loss = model.get_latest_training_loss()
        if self.epoch == 1:
            current_loss = loss
        else:
            current_loss = loss - self.loss_previous_step
        print(f"Loss after epoch {self.epoch}: {current_loss}")
        self.training_loss.append(current_loss)
        self.epoch += 1
        self.loss_previous_step = loss

# %%
logging.disable(logging.NOTSET) # enable logging
t = time()

model_song.build_vocab(train_word)
# Out:
# 2022-12-02 15:18:56,284 : INFO : collecting all words and their counts
# 2022-12-02 15:18:56,284 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-12-02 15:18:56,302 : INFO : PROGRESS: at sentence #10000, processed 102656 words, keeping 12905 word types
# 2022-12-02 15:18:56,320 : INFO : PROGRESS: at sentence #20000, processed 205849 words, keeping 19326 word types
# 2022-12-02 15:18:56,341 : INFO : PROGRESS: at sentence #30000, processed 309443 words, keeping 24425 word types
# 2022-12-02 15:18:56,360 : INFO : PROGRESS: at sentence #40000, processed 413022 words, keeping 28969 word types
# 2022-12-02 15:18:56,380 : INFO : PROGRESS: at sentence #50000, processed 514883 words, keeping 32798 word types
# 2022-12-02 15:18:56,400 : INFO : PROGRESS: at sentence #60000, processed 617718 words, keeping 36348 word types
# 2022-12-02 15:18:56,420 : INFO : PROGRESS: at sentence #70000, processed 721389 words, keeping 39676 word types
# 2022-12-02 15:18:56,441 : INFO : PROGRESS: at sentence #80000, processed 823987 words, keeping 42776 word types
# 2022-12-02 15:18:56,465 : INFO : PROGRESS: at sentence #90000, processed 927441 words, keeping 45683 word types
# 2022-12-02 15:18:56,482 : INFO : PROGRESS: at sentence #100000, processed 1007757 words, keeping 47568 word types
# 2022-12-02 15:18:56,498 : INFO : PROGRESS: at sentence #110000, processed 1081052 words, keeping 49225 word types
# 2022-12-02 15:18:56,506 : INFO : collected 50095 word types from a corpus of 1118062 raw words and 115071 sentences
# 2022-12-02 15:18:56,507 : INFO : Creating a fresh vocabulary
# 2022-12-02 15:18:56,641 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 50095 unique words (100.0%% of original 50095, drops 0)', 'datetime': '2022-12-02T15:18:56.641720', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# 2022-12-02 15:18:56,641 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 1118062 word corpus (100.0%% of original 1118062, drops 0)', 'datetime': '2022-12-02T15:18:56.641720', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# 2022-12-02 15:18:56,834 : INFO : deleting the raw counts dictionary of 50095 items
# 2022-12-02 15:18:56,835 : INFO : sample=0.001 downsamples 56 most-common words
# 2022-12-02 15:18:56,836 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 949548.5194845407 word corpus (84.9%% of prior 1118062)', 'datetime': '2022-12-02T15:18:56.836720', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'prepare_vocab'}
# 2022-12-02 15:18:57,124 : INFO : estimated required memory for 50095 words and 100 dimensions: 65123500 bytes
# 2022-12-02 15:18:57,125 : INFO : resetting layer weights
# 2022-12-02 15:18:57,138 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-12-02T15:18:57.138720', 'gensim': '4.1.2', 'python': '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19044-SP0', 'event': 'build_vocab'}

# %%
model_song.corpus_count
# Out:
# 115071

# %%
# %%time
logging.disable(logging.INFO) # disable logging
callback = Callback() # instead, print out loss for each epoch
t = time()

model_song.train(train_word,
            total_examples = model_song.corpus_count,
            epochs = 10,
            compute_loss = True,
            callbacks = [callback]) 

model_song.save("title_tags2vec(word2vec(title&tags only)).model")
print(model_song)
# Out:
# Loss after epoch 1: 6521085.0
# Loss after epoch 2: 5716906.0
# Loss after epoch 3: 5579291.0
# Loss after epoch 4: 5371856.0
# Loss after epoch 5: 5358266.0
# Loss after epoch 6: 5347288.0
# Loss after epoch 7: 5474468.0
# Loss after epoch 8: 5501644.0
# Loss after epoch 9: 5512680.0
# Loss after epoch 10: 5592236.0
# Word2Vec(vocab=50095, vector_size=100, alpha=0.025)
# Wall time: 1min 57s
